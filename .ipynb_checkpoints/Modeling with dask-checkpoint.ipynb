# %% [markdown]
# # Clustering Client

# %%
from dask.distributed import Client

client = Client("tcp://127.0.0.1:53140")
client
# Out:
# <Client: 'tcp://127.0.0.1:53140' processes=4 threads=4, memory=17.18 GB>

# %%
import dask.array as da
import dask.dataframe as dd
import pandas as pd
import numpy as np
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
from sklearn import decomposition
from sklearn import manifold
from sklearn import metrics
from dask_ml import preprocessing


sns.set_style("whitegrid")
# %matplotlib inline
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1 - Import des jeux de données

# %%
data_3_months = dd.read_csv(
    "data/clean/data_3_months.csv", parse_dates=["order_purchase_timestamp"])
data_6_months = dd.read_csv(
    "data/clean/data_6_months.csv", parse_dates=["order_purchase_timestamp"])
data_9_months = dd.read_csv(
    "data/clean/data_9_months.csv", parse_dates=["order_purchase_timestamp"])
data_12_months = dd.read_csv(
    "data/clean/data_12_months.csv", parse_dates=["order_purchase_timestamp"])
data_15_months = dd.read_csv(
    "data/clean/data_15_months.csv", parse_dates=["order_purchase_timestamp"])
data_18_months = dd.read_csv(
    "data/clean/data_18_months.csv", parse_dates=["order_purchase_timestamp"])
data_all = dd.read_csv("data/clean/data_all.csv",
                       parse_dates=["order_purchase_timestamp"])

# %% [markdown]
# ## 2 - Features engineering

# %%
def review(df):
    grouped = df.groupby("customer_unique_id").agg(
        {"review_score": ["count", "min", "max", "mean"]})
    grouped.columns = ["_".join(x) for x in grouped.columns.ravel()]
    return grouped


def value(df):
    grouped = df.groupby("customer_unique_id").agg({
        "payment_value": ["mean", "min", "max"]})
    grouped.columns = ["_".join(x) for x in grouped.columns.ravel()]
    return grouped


def payment_facility(df):
    df_pf = df.groupby("customer_unique_id").agg({
        "payment_installments": "sum"
    })
    cond_mask = (df_pf["payment_installments"] > 1)

    df_pf["payment_installments"] = df_pf["payment_installments"].mask(
        cond=cond_mask, other=0)
    df_pf = df_pf.rename(columns={"payment_installments": "payment_facility"})
    return df_pf


def category_transf(df):
    df_ct = dd.get_dummies(df[["product_category_name", "customer_unique_id"]].categorize(
    ), columns=['product_category_name'], prefix="PCat").groupby(['customer_unique_id']).sum()
    return df_ct


def state(df):
    df_state = dd.get_dummies(df[["customer_state", "customer_unique_id"]].categorize(
    ), columns=["customer_state"], prefix="CState").groupby(["customer_unique_id"]).sum()
    return df_state


def payment(df):
    df_p = dd.get_dummies(df[["payment_type", "customer_unique_id"]].categorize(
    ), columns=['payment_type'], prefix="PType").groupby(['customer_unique_id']).sum()
    return df_p


def rfm(df):
    df = df.compute()
    return df.groupby("customer_unique_id").agg(
        recency=("order_purchase_timestamp", lambda date: (
            df["order_purchase_timestamp"].max() - date.max()).days),
        frequency=("order_id", "count"),
        monetary=("payment_value", sum))


def features_engineering(df):
    df_fe = dd.merge(rfm(df), value(df))
    df_fe = dd.merge(df_fe, review(df))
    df_fe = dd.merge(df_fe, payment(df))
    df_fe = dd.merge(df_fe, state(df))
    df_fe = dd.merge(df_fe, category_transf(df))
    df_fe = dd.merge(df_fe, payment_facility(df))
    return df_fe

# %%
data_3_months_fe = features_engineering(data_3_months).compute()
data_3_months_fe.head()
# Out:
#                                   recency  frequency  monetary  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064       20          1     86.22
# 0005e1862207bf6ccc02e4228effd9a0       26          1    150.12
# 00115fc7123b5310cf6d3a3aa932699e       68          1     76.11
# 001f3c4211216384d5fe59b041ce1461       11          1     35.84
# 002043098f10ba39a4600b6c52fbfe3c        4          1    237.81
#
#                                   payment_value_mean  payment_value_min  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064               86.22              86.22
# 0005e1862207bf6ccc02e4228effd9a0              150.12             150.12
# 00115fc7123b5310cf6d3a3aa932699e               76.11              76.11
# 001f3c4211216384d5fe59b041ce1461               35.84              35.84
# 002043098f10ba39a4600b6c52fbfe3c              237.81             237.81
#
#                                   payment_value_max  review_score_count  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064              86.22                   1
# 0005e1862207bf6ccc02e4228effd9a0             150.12                   1
# 00115fc7123b5310cf6d3a3aa932699e              76.11                   1
# 001f3c4211216384d5fe59b041ce1461              35.84                   1
# 002043098f10ba39a4600b6c52fbfe3c             237.81                   1
#
#                                   review_score_min  review_score_max  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                 3                 3
# 0005e1862207bf6ccc02e4228effd9a0                 4                 4
# 00115fc7123b5310cf6d3a3aa932699e                 4                 4
# 001f3c4211216384d5fe59b041ce1461                 3                 3
# 002043098f10ba39a4600b6c52fbfe3c                 4                 4
#
#                                   review_score_mean  ...  \
# customer_unique_id                                   ...
# 0000f46a3911fa3c0805444483337064                3.0  ...
# 0005e1862207bf6ccc02e4228effd9a0                4.0  ...
# 00115fc7123b5310cf6d3a3aa932699e                4.0  ...
# 001f3c4211216384d5fe59b041ce1461                3.0  ...
# 002043098f10ba39a4600b6c52fbfe3c                4.0  ...
#
#                                   PCat_fashion_underwear_beach  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                             0
# 0005e1862207bf6ccc02e4228effd9a0                             0
# 00115fc7123b5310cf6d3a3aa932699e                             0
# 001f3c4211216384d5fe59b041ce1461                             0
# 002043098f10ba39a4600b6c52fbfe3c                             0
#
#                                   PCat_books_technical  PCat_dvds_blu_ray  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                     0                  0
# 0005e1862207bf6ccc02e4228effd9a0                     0                  0
# 00115fc7123b5310cf6d3a3aa932699e                     0                  0
# 001f3c4211216384d5fe59b041ce1461                     0                  0
# 002043098f10ba39a4600b6c52fbfe3c                     0                  0
#
#                                   PCat_security_and_services  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                           0
# 0005e1862207bf6ccc02e4228effd9a0                           0
# 00115fc7123b5310cf6d3a3aa932699e                           0
# 001f3c4211216384d5fe59b041ce1461                           0
# 002043098f10ba39a4600b6c52fbfe3c                           0
#
#                                   PCat_tablets_printing_image  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                            0
# 0005e1862207bf6ccc02e4228effd9a0                            0
# 00115fc7123b5310cf6d3a3aa932699e                            0
# 001f3c4211216384d5fe59b041ce1461                            0
# 002043098f10ba39a4600b6c52fbfe3c                            0
#
#                                   PCat_furniture_bedroom  PCat_cine_photo  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                       0                0
# 0005e1862207bf6ccc02e4228effd9a0                       0                0
# 00115fc7123b5310cf6d3a3aa932699e                       0                0
# 001f3c4211216384d5fe59b041ce1461                       0                0
# 002043098f10ba39a4600b6c52fbfe3c                       0                0
#
#                                   PCat_fashio_female_clothing  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                            0
# 0005e1862207bf6ccc02e4228effd9a0                            0
# 00115fc7123b5310cf6d3a3aa932699e                            0
# 001f3c4211216384d5fe59b041ce1461                            0
# 002043098f10ba39a4600b6c52fbfe3c                            0
#
#                                   PCat_books_imported  payment_facility
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                    0                 0
# 0005e1862207bf6ccc02e4228effd9a0                    0                 0
# 00115fc7123b5310cf6d3a3aa932699e                    0                 1
# 001f3c4211216384d5fe59b041ce1461                    0                 0
# 002043098f10ba39a4600b6c52fbfe3c                    0                 0
#
# [5 rows x 101 columns]

# %%
data_6_months_fe = features_engineering(data_6_months).compute()
data_6_months_fe.head()
# Out:
#                                   recency  frequency  monetary  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064      111          1     86.22
# 0005e1862207bf6ccc02e4228effd9a0      116          1    150.12
# 00115fc7123b5310cf6d3a3aa932699e      159          1     76.11
# 0011805441c0d1b68b48002f1d005526       66          1    297.14
# 0011857aff0e5871ce5eb429f21cdaf5        1          1    192.83
#
#                                   payment_value_mean  payment_value_min  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064               86.22              86.22
# 0005e1862207bf6ccc02e4228effd9a0              150.12             150.12
# 00115fc7123b5310cf6d3a3aa932699e               76.11              76.11
# 0011805441c0d1b68b48002f1d005526              297.14             297.14
# 0011857aff0e5871ce5eb429f21cdaf5              192.83             192.83
#
#                                   payment_value_max  review_score_count  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064              86.22                   1
# 0005e1862207bf6ccc02e4228effd9a0             150.12                   1
# 00115fc7123b5310cf6d3a3aa932699e              76.11                   1
# 0011805441c0d1b68b48002f1d005526             297.14                   1
# 0011857aff0e5871ce5eb429f21cdaf5             192.83                   1
#
#                                   review_score_min  review_score_max  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                 3                 3
# 0005e1862207bf6ccc02e4228effd9a0                 4                 4
# 00115fc7123b5310cf6d3a3aa932699e                 4                 4
# 0011805441c0d1b68b48002f1d005526                 3                 3
# 0011857aff0e5871ce5eb429f21cdaf5                 5                 5
#
#                                   review_score_mean  ...  \
# customer_unique_id                                   ...
# 0000f46a3911fa3c0805444483337064                3.0  ...
# 0005e1862207bf6ccc02e4228effd9a0                4.0  ...
# 00115fc7123b5310cf6d3a3aa932699e                4.0  ...
# 0011805441c0d1b68b48002f1d005526                3.0  ...
# 0011857aff0e5871ce5eb429f21cdaf5                5.0  ...
#
#                                   PCat_books_technical  PCat_dvds_blu_ray  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                     0                  0
# 0005e1862207bf6ccc02e4228effd9a0                     0                  0
# 00115fc7123b5310cf6d3a3aa932699e                     0                  0
# 0011805441c0d1b68b48002f1d005526                     0                  0
# 0011857aff0e5871ce5eb429f21cdaf5                     0                  0
#
#                                   PCat_security_and_services  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                           0
# 0005e1862207bf6ccc02e4228effd9a0                           0
# 00115fc7123b5310cf6d3a3aa932699e                           0
# 0011805441c0d1b68b48002f1d005526                           0
# 0011857aff0e5871ce5eb429f21cdaf5                           0
#
#                                   PCat_tablets_printing_image  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                            0
# 0005e1862207bf6ccc02e4228effd9a0                            0
# 00115fc7123b5310cf6d3a3aa932699e                            0
# 0011805441c0d1b68b48002f1d005526                            0
# 0011857aff0e5871ce5eb429f21cdaf5                            0
#
#                                   PCat_furniture_bedroom  PCat_cine_photo  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                       0                0
# 0005e1862207bf6ccc02e4228effd9a0                       0                0
# 00115fc7123b5310cf6d3a3aa932699e                       0                0
# 0011805441c0d1b68b48002f1d005526                       0                0
# 0011857aff0e5871ce5eb429f21cdaf5                       0                0
#
#                                   PCat_fashio_female_clothing  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                            0
# 0005e1862207bf6ccc02e4228effd9a0                            0
# 00115fc7123b5310cf6d3a3aa932699e                            0
# 0011805441c0d1b68b48002f1d005526                            0
# 0011857aff0e5871ce5eb429f21cdaf5                            0
#
#                                   PCat_books_imported  PCat_la_cuisine  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                    0                0
# 0005e1862207bf6ccc02e4228effd9a0                    0                0
# 00115fc7123b5310cf6d3a3aa932699e                    0                0
# 0011805441c0d1b68b48002f1d005526                    0                0
# 0011857aff0e5871ce5eb429f21cdaf5                    0                0
#
#                                   payment_facility
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                 0
# 0005e1862207bf6ccc02e4228effd9a0                 0
# 00115fc7123b5310cf6d3a3aa932699e                 1
# 0011805441c0d1b68b48002f1d005526                 0
# 0011857aff0e5871ce5eb429f21cdaf5                 0
#
# [5 rows x 107 columns]

# %%
data_9_months_fe = features_engineering(data_9_months).compute()
data_9_months_fe.head()
# Out:
#                                   recency  frequency  monetary  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064      203          1     86.22
# 0005e1862207bf6ccc02e4228effd9a0      209          1    150.12
# 0006fdc98a402fceb4eb0ee528f6a8d4       73          1     29.00
# 000a5ad9c4601d2bbdd9ed765d5213b3       49          1     91.28
# 000bfa1d2f1a41876493be685390d6d3        0          2     93.70
#
#                                   payment_value_mean  payment_value_min  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064               86.22              86.22
# 0005e1862207bf6ccc02e4228effd9a0              150.12             150.12
# 0006fdc98a402fceb4eb0ee528f6a8d4               29.00              29.00
# 000a5ad9c4601d2bbdd9ed765d5213b3               91.28              91.28
# 000bfa1d2f1a41876493be685390d6d3               46.85              46.85
#
#                                   payment_value_max  review_score_count  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064              86.22                   1
# 0005e1862207bf6ccc02e4228effd9a0             150.12                   1
# 0006fdc98a402fceb4eb0ee528f6a8d4              29.00                   1
# 000a5ad9c4601d2bbdd9ed765d5213b3              91.28                   1
# 000bfa1d2f1a41876493be685390d6d3              46.85                   2
#
#                                   review_score_min  review_score_max  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                 3                 3
# 0005e1862207bf6ccc02e4228effd9a0                 4                 4
# 0006fdc98a402fceb4eb0ee528f6a8d4                 3                 3
# 000a5ad9c4601d2bbdd9ed765d5213b3                 4                 4
# 000bfa1d2f1a41876493be685390d6d3                 4                 5
#
#                                   review_score_mean  ...  PCat_dvds_blu_ray  \
# customer_unique_id                                   ...
# 0000f46a3911fa3c0805444483337064                3.0  ...                  0
# 0005e1862207bf6ccc02e4228effd9a0                4.0  ...                  0
# 0006fdc98a402fceb4eb0ee528f6a8d4                3.0  ...                  0
# 000a5ad9c4601d2bbdd9ed765d5213b3                4.0  ...                  0
# 000bfa1d2f1a41876493be685390d6d3                4.5  ...                  0
#
#                                   PCat_cds_dvds_musicals  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                       0
# 0005e1862207bf6ccc02e4228effd9a0                       0
# 0006fdc98a402fceb4eb0ee528f6a8d4                       0
# 000a5ad9c4601d2bbdd9ed765d5213b3                       0
# 000bfa1d2f1a41876493be685390d6d3                       0
#
#                                   PCat_security_and_services  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                           0
# 0005e1862207bf6ccc02e4228effd9a0                           0
# 0006fdc98a402fceb4eb0ee528f6a8d4                           0
# 000a5ad9c4601d2bbdd9ed765d5213b3                           0
# 000bfa1d2f1a41876493be685390d6d3                           0
#
#                                   PCat_tablets_printing_image  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                            0
# 0005e1862207bf6ccc02e4228effd9a0                            0
# 0006fdc98a402fceb4eb0ee528f6a8d4                            0
# 000a5ad9c4601d2bbdd9ed765d5213b3                            0
# 000bfa1d2f1a41876493be685390d6d3                            0
#
#                                   PCat_furniture_bedroom  PCat_cine_photo  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                       0                0
# 0005e1862207bf6ccc02e4228effd9a0                       0                0
# 0006fdc98a402fceb4eb0ee528f6a8d4                       0                0
# 000a5ad9c4601d2bbdd9ed765d5213b3                       0                0
# 000bfa1d2f1a41876493be685390d6d3                       0                0
#
#                                   PCat_fashio_female_clothing  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                            0
# 0005e1862207bf6ccc02e4228effd9a0                            0
# 0006fdc98a402fceb4eb0ee528f6a8d4                            0
# 000a5ad9c4601d2bbdd9ed765d5213b3                            0
# 000bfa1d2f1a41876493be685390d6d3                            0
#
#                                   PCat_books_imported  PCat_la_cuisine  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                    0                0
# 0005e1862207bf6ccc02e4228effd9a0                    0                0
# 0006fdc98a402fceb4eb0ee528f6a8d4                    0                0
# 000a5ad9c4601d2bbdd9ed765d5213b3                    0                0
# 000bfa1d2f1a41876493be685390d6d3                    0                0
#
#                                   payment_facility
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                 0
# 0005e1862207bf6ccc02e4228effd9a0                 0
# 0006fdc98a402fceb4eb0ee528f6a8d4                 0
# 000a5ad9c4601d2bbdd9ed765d5213b3                 0
# 000bfa1d2f1a41876493be685390d6d3                 0
#
# [5 rows x 111 columns]

# %%
data_12_months_fe = features_engineering(data_12_months).compute()
data_12_months_fe.head()
# Out:
#                                   recency  frequency  monetary  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064      295          1     86.22
# 0000f6ccb0745a6a4b88665a16c9f078       79          1     43.62
# 0004aac84e0df4da2b147fca70cf8255       46          1    196.89
# 0005e1862207bf6ccc02e4228effd9a0      301          1    150.12
# 0006fdc98a402fceb4eb0ee528f6a8d4      165          1     29.00
#
#                                   payment_value_mean  payment_value_min  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064               86.22              86.22
# 0000f6ccb0745a6a4b88665a16c9f078               43.62              43.62
# 0004aac84e0df4da2b147fca70cf8255              196.89             196.89
# 0005e1862207bf6ccc02e4228effd9a0              150.12             150.12
# 0006fdc98a402fceb4eb0ee528f6a8d4               29.00              29.00
#
#                                   payment_value_max  review_score_count  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064              86.22                   1
# 0000f6ccb0745a6a4b88665a16c9f078              43.62                   1
# 0004aac84e0df4da2b147fca70cf8255             196.89                   1
# 0005e1862207bf6ccc02e4228effd9a0             150.12                   1
# 0006fdc98a402fceb4eb0ee528f6a8d4              29.00                   1
#
#                                   review_score_min  review_score_max  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                 3                 3
# 0000f6ccb0745a6a4b88665a16c9f078                 4                 4
# 0004aac84e0df4da2b147fca70cf8255                 5                 5
# 0005e1862207bf6ccc02e4228effd9a0                 4                 4
# 0006fdc98a402fceb4eb0ee528f6a8d4                 3                 3
#
#                                   review_score_mean  ...  \
# customer_unique_id                                   ...
# 0000f46a3911fa3c0805444483337064                3.0  ...
# 0000f6ccb0745a6a4b88665a16c9f078                4.0  ...
# 0004aac84e0df4da2b147fca70cf8255                5.0  ...
# 0005e1862207bf6ccc02e4228effd9a0                4.0  ...
# 0006fdc98a402fceb4eb0ee528f6a8d4                3.0  ...
#
#                                   PCat_cds_dvds_musicals  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                       0
# 0000f6ccb0745a6a4b88665a16c9f078                       0
# 0004aac84e0df4da2b147fca70cf8255                       0
# 0005e1862207bf6ccc02e4228effd9a0                       0
# 0006fdc98a402fceb4eb0ee528f6a8d4                       0
#
#                                   PCat_security_and_services  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                           0
# 0000f6ccb0745a6a4b88665a16c9f078                           0
# 0004aac84e0df4da2b147fca70cf8255                           0
# 0005e1862207bf6ccc02e4228effd9a0                           0
# 0006fdc98a402fceb4eb0ee528f6a8d4                           0
#
#                                   PCat_tablets_printing_image  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                            0
# 0000f6ccb0745a6a4b88665a16c9f078                            0
# 0004aac84e0df4da2b147fca70cf8255                            0
# 0005e1862207bf6ccc02e4228effd9a0                            0
# 0006fdc98a402fceb4eb0ee528f6a8d4                            0
#
#                                   PCat_furniture_bedroom  PCat_cine_photo  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                       0                0
# 0000f6ccb0745a6a4b88665a16c9f078                       0                0
# 0004aac84e0df4da2b147fca70cf8255                       0                0
# 0005e1862207bf6ccc02e4228effd9a0                       0                0
# 0006fdc98a402fceb4eb0ee528f6a8d4                       0                0
#
#                                   PCat_fashio_female_clothing  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                            0
# 0000f6ccb0745a6a4b88665a16c9f078                            0
# 0004aac84e0df4da2b147fca70cf8255                            0
# 0005e1862207bf6ccc02e4228effd9a0                            0
# 0006fdc98a402fceb4eb0ee528f6a8d4                            0
#
#                                   PCat_diapers_and_hygiene  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                         0
# 0000f6ccb0745a6a4b88665a16c9f078                         0
# 0004aac84e0df4da2b147fca70cf8255                         0
# 0005e1862207bf6ccc02e4228effd9a0                         0
# 0006fdc98a402fceb4eb0ee528f6a8d4                         0
#
#                                   PCat_books_imported  PCat_la_cuisine  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                    0                0
# 0000f6ccb0745a6a4b88665a16c9f078                    0                0
# 0004aac84e0df4da2b147fca70cf8255                    0                0
# 0005e1862207bf6ccc02e4228effd9a0                    0                0
# 0006fdc98a402fceb4eb0ee528f6a8d4                    0                0
#
#                                   payment_facility
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                 0
# 0000f6ccb0745a6a4b88665a16c9f078                 0
# 0004aac84e0df4da2b147fca70cf8255                 0
# 0005e1862207bf6ccc02e4228effd9a0                 0
# 0006fdc98a402fceb4eb0ee528f6a8d4                 0
#
# [5 rows x 113 columns]

# %%
data_15_months_fe = features_engineering(data_15_months).compute()
data_15_months_fe.head()
# Out:
#                                   recency  frequency  monetary  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064      385          1     86.22
# 0000f6ccb0745a6a4b88665a16c9f078      169          1     43.62
# 0004aac84e0df4da2b147fca70cf8255      136          1    196.89
# 00053a61a98854899e70ed204dd4bafe       30          2    838.36
# 0005e1862207bf6ccc02e4228effd9a0      391          1    150.12
#
#                                   payment_value_mean  payment_value_min  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064               86.22              86.22
# 0000f6ccb0745a6a4b88665a16c9f078               43.62              43.62
# 0004aac84e0df4da2b147fca70cf8255              196.89             196.89
# 00053a61a98854899e70ed204dd4bafe              419.18             419.18
# 0005e1862207bf6ccc02e4228effd9a0              150.12             150.12
#
#                                   payment_value_max  review_score_count  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064              86.22                   1
# 0000f6ccb0745a6a4b88665a16c9f078              43.62                   1
# 0004aac84e0df4da2b147fca70cf8255             196.89                   1
# 00053a61a98854899e70ed204dd4bafe             419.18                   2
# 0005e1862207bf6ccc02e4228effd9a0             150.12                   1
#
#                                   review_score_min  review_score_max  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                 3                 3
# 0000f6ccb0745a6a4b88665a16c9f078                 4                 4
# 0004aac84e0df4da2b147fca70cf8255                 5                 5
# 00053a61a98854899e70ed204dd4bafe                 1                 1
# 0005e1862207bf6ccc02e4228effd9a0                 4                 4
#
#                                   review_score_mean  ...  \
# customer_unique_id                                   ...
# 0000f46a3911fa3c0805444483337064                3.0  ...
# 0000f6ccb0745a6a4b88665a16c9f078                4.0  ...
# 0004aac84e0df4da2b147fca70cf8255                5.0  ...
# 00053a61a98854899e70ed204dd4bafe                1.0  ...
# 0005e1862207bf6ccc02e4228effd9a0                4.0  ...
#
#                                   PCat_cds_dvds_musicals  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                       0
# 0000f6ccb0745a6a4b88665a16c9f078                       0
# 0004aac84e0df4da2b147fca70cf8255                       0
# 00053a61a98854899e70ed204dd4bafe                       0
# 0005e1862207bf6ccc02e4228effd9a0                       0
#
#                                   PCat_security_and_services  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                           0
# 0000f6ccb0745a6a4b88665a16c9f078                           0
# 0004aac84e0df4da2b147fca70cf8255                           0
# 00053a61a98854899e70ed204dd4bafe                           0
# 0005e1862207bf6ccc02e4228effd9a0                           0
#
#                                   PCat_tablets_printing_image  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                            0
# 0000f6ccb0745a6a4b88665a16c9f078                            0
# 0004aac84e0df4da2b147fca70cf8255                            0
# 00053a61a98854899e70ed204dd4bafe                            0
# 0005e1862207bf6ccc02e4228effd9a0                            0
#
#                                   PCat_furniture_bedroom  PCat_cine_photo  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                       0                0
# 0000f6ccb0745a6a4b88665a16c9f078                       0                0
# 0004aac84e0df4da2b147fca70cf8255                       0                0
# 00053a61a98854899e70ed204dd4bafe                       0                0
# 0005e1862207bf6ccc02e4228effd9a0                       0                0
#
#                                   PCat_fashio_female_clothing  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                            0
# 0000f6ccb0745a6a4b88665a16c9f078                            0
# 0004aac84e0df4da2b147fca70cf8255                            0
# 00053a61a98854899e70ed204dd4bafe                            0
# 0005e1862207bf6ccc02e4228effd9a0                            0
#
#                                   PCat_diapers_and_hygiene  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                         0
# 0000f6ccb0745a6a4b88665a16c9f078                         0
# 0004aac84e0df4da2b147fca70cf8255                         0
# 00053a61a98854899e70ed204dd4bafe                         0
# 0005e1862207bf6ccc02e4228effd9a0                         0
#
#                                   PCat_books_imported  PCat_la_cuisine  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                    0                0
# 0000f6ccb0745a6a4b88665a16c9f078                    0                0
# 0004aac84e0df4da2b147fca70cf8255                    0                0
# 00053a61a98854899e70ed204dd4bafe                    0                0
# 0005e1862207bf6ccc02e4228effd9a0                    0                0
#
#                                   payment_facility
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                 0
# 0000f6ccb0745a6a4b88665a16c9f078                 0
# 0004aac84e0df4da2b147fca70cf8255                 0
# 00053a61a98854899e70ed204dd4bafe                 0
# 0005e1862207bf6ccc02e4228effd9a0                 0
#
# [5 rows x 113 columns]

# %%
data_18_months_fe = features_engineering(data_18_months).compute()
data_18_months_fe.head()
# Out:
#                                   recency  frequency  monetary  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2       50          1    141.90
# 0000b849f77a49e4a4ce2b2a4ca5be3f       53          1     27.19
# 0000f46a3911fa3c0805444483337064      476          1     86.22
# 0000f6ccb0745a6a4b88665a16c9f078      260          1     43.62
# 0004aac84e0df4da2b147fca70cf8255      227          1    196.89
#
#                                   payment_value_mean  payment_value_min  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2              141.90             141.90
# 0000b849f77a49e4a4ce2b2a4ca5be3f               27.19              27.19
# 0000f46a3911fa3c0805444483337064               86.22              86.22
# 0000f6ccb0745a6a4b88665a16c9f078               43.62              43.62
# 0004aac84e0df4da2b147fca70cf8255              196.89             196.89
#
#                                   payment_value_max  review_score_count  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2             141.90                   1
# 0000b849f77a49e4a4ce2b2a4ca5be3f              27.19                   1
# 0000f46a3911fa3c0805444483337064              86.22                   1
# 0000f6ccb0745a6a4b88665a16c9f078              43.62                   1
# 0004aac84e0df4da2b147fca70cf8255             196.89                   1
#
#                                   review_score_min  review_score_max  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                 5                 5
# 0000b849f77a49e4a4ce2b2a4ca5be3f                 4                 4
# 0000f46a3911fa3c0805444483337064                 3                 3
# 0000f6ccb0745a6a4b88665a16c9f078                 4                 4
# 0004aac84e0df4da2b147fca70cf8255                 5                 5
#
#                                   review_score_mean  ...  \
# customer_unique_id                                   ...
# 0000366f3b9a7992bf8c76cfdf3221e2                5.0  ...
# 0000b849f77a49e4a4ce2b2a4ca5be3f                4.0  ...
# 0000f46a3911fa3c0805444483337064                3.0  ...
# 0000f6ccb0745a6a4b88665a16c9f078                4.0  ...
# 0004aac84e0df4da2b147fca70cf8255                5.0  ...
#
#                                   PCat_cds_dvds_musicals  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                       0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                       0
# 0000f46a3911fa3c0805444483337064                       0
# 0000f6ccb0745a6a4b88665a16c9f078                       0
# 0004aac84e0df4da2b147fca70cf8255                       0
#
#                                   PCat_security_and_services  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                           0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                           0
# 0000f46a3911fa3c0805444483337064                           0
# 0000f6ccb0745a6a4b88665a16c9f078                           0
# 0004aac84e0df4da2b147fca70cf8255                           0
#
#                                   PCat_tablets_printing_image  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                            0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                            0
# 0000f46a3911fa3c0805444483337064                            0
# 0000f6ccb0745a6a4b88665a16c9f078                            0
# 0004aac84e0df4da2b147fca70cf8255                            0
#
#                                   PCat_furniture_bedroom  PCat_cine_photo  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                       0                0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                       0                0
# 0000f46a3911fa3c0805444483337064                       0                0
# 0000f6ccb0745a6a4b88665a16c9f078                       0                0
# 0004aac84e0df4da2b147fca70cf8255                       0                0
#
#                                   PCat_fashio_female_clothing  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                            0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                            0
# 0000f46a3911fa3c0805444483337064                            0
# 0000f6ccb0745a6a4b88665a16c9f078                            0
# 0004aac84e0df4da2b147fca70cf8255                            0
#
#                                   PCat_diapers_and_hygiene  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                         0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                         0
# 0000f46a3911fa3c0805444483337064                         0
# 0000f6ccb0745a6a4b88665a16c9f078                         0
# 0004aac84e0df4da2b147fca70cf8255                         0
#
#                                   PCat_books_imported  PCat_la_cuisine  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                    0                0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                    0                0
# 0000f46a3911fa3c0805444483337064                    0                0
# 0000f6ccb0745a6a4b88665a16c9f078                    0                0
# 0004aac84e0df4da2b147fca70cf8255                    0                0
#
#                                   payment_facility
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                 0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                 1
# 0000f46a3911fa3c0805444483337064                 0
# 0000f6ccb0745a6a4b88665a16c9f078                 0
# 0004aac84e0df4da2b147fca70cf8255                 0
#
# [5 rows x 113 columns]

# %%
data_all_fe = features_engineering(data_all).compute()
data_all_fe.head()
# Out:
#                                   recency  frequency  monetary  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2      115          1    141.90
# 0000b849f77a49e4a4ce2b2a4ca5be3f      118          1     27.19
# 0000f46a3911fa3c0805444483337064      541          1     86.22
# 0000f6ccb0745a6a4b88665a16c9f078      325          1     43.62
# 0004aac84e0df4da2b147fca70cf8255      292          1    196.89
#
#                                   payment_value_mean  payment_value_min  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2              141.90             141.90
# 0000b849f77a49e4a4ce2b2a4ca5be3f               27.19              27.19
# 0000f46a3911fa3c0805444483337064               86.22              86.22
# 0000f6ccb0745a6a4b88665a16c9f078               43.62              43.62
# 0004aac84e0df4da2b147fca70cf8255              196.89             196.89
#
#                                   payment_value_max  review_score_count  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2             141.90                   1
# 0000b849f77a49e4a4ce2b2a4ca5be3f              27.19                   1
# 0000f46a3911fa3c0805444483337064              86.22                   1
# 0000f6ccb0745a6a4b88665a16c9f078              43.62                   1
# 0004aac84e0df4da2b147fca70cf8255             196.89                   1
#
#                                   review_score_min  review_score_max  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                 5                 5
# 0000b849f77a49e4a4ce2b2a4ca5be3f                 4                 4
# 0000f46a3911fa3c0805444483337064                 3                 3
# 0000f6ccb0745a6a4b88665a16c9f078                 4                 4
# 0004aac84e0df4da2b147fca70cf8255                 5                 5
#
#                                   review_score_mean  ...  \
# customer_unique_id                                   ...
# 0000366f3b9a7992bf8c76cfdf3221e2                5.0  ...
# 0000b849f77a49e4a4ce2b2a4ca5be3f                4.0  ...
# 0000f46a3911fa3c0805444483337064                3.0  ...
# 0000f6ccb0745a6a4b88665a16c9f078                4.0  ...
# 0004aac84e0df4da2b147fca70cf8255                5.0  ...
#
#                                   PCat_cds_dvds_musicals  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                       0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                       0
# 0000f46a3911fa3c0805444483337064                       0
# 0000f6ccb0745a6a4b88665a16c9f078                       0
# 0004aac84e0df4da2b147fca70cf8255                       0
#
#                                   PCat_security_and_services  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                           0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                           0
# 0000f46a3911fa3c0805444483337064                           0
# 0000f6ccb0745a6a4b88665a16c9f078                           0
# 0004aac84e0df4da2b147fca70cf8255                           0
#
#                                   PCat_tablets_printing_image  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                            0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                            0
# 0000f46a3911fa3c0805444483337064                            0
# 0000f6ccb0745a6a4b88665a16c9f078                            0
# 0004aac84e0df4da2b147fca70cf8255                            0
#
#                                   PCat_furniture_bedroom  PCat_cine_photo  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                       0                0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                       0                0
# 0000f46a3911fa3c0805444483337064                       0                0
# 0000f6ccb0745a6a4b88665a16c9f078                       0                0
# 0004aac84e0df4da2b147fca70cf8255                       0                0
#
#                                   PCat_fashio_female_clothing  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                            0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                            0
# 0000f46a3911fa3c0805444483337064                            0
# 0000f6ccb0745a6a4b88665a16c9f078                            0
# 0004aac84e0df4da2b147fca70cf8255                            0
#
#                                   PCat_diapers_and_hygiene  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                         0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                         0
# 0000f46a3911fa3c0805444483337064                         0
# 0000f6ccb0745a6a4b88665a16c9f078                         0
# 0004aac84e0df4da2b147fca70cf8255                         0
#
#                                   PCat_books_imported  PCat_la_cuisine  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                    0                0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                    0                0
# 0000f46a3911fa3c0805444483337064                    0                0
# 0000f6ccb0745a6a4b88665a16c9f078                    0                0
# 0004aac84e0df4da2b147fca70cf8255                    0                0
#
#                                   payment_facility
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                 0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                 1
# 0000f46a3911fa3c0805444483337064                 0
# 0000f6ccb0745a6a4b88665a16c9f078                 0
# 0004aac84e0df4da2b147fca70cf8255                 0
#
# [5 rows x 113 columns]

# %% [markdown]
# On enregistre les jeux de données pour revenir dessus plus tard

# %%
data_3_months_fe.to_csv("data/fe/data_3_months.csv")
data_6_months_fe.to_csv("data/fe/data_6_months.csv")
data_9_months_fe.to_csv("data/fe/data_9_months.csv")
data_12_months_fe.to_csv("data/fe/data_12_months.csv")
data_15_months_fe.to_csv("data/fe/data_15_months.csv")
data_18_months_fe.to_csv("data/fe/data_18_months.csv")
data_all_fe.to_csv("data/fe/data_all.csv")

# %% [markdown]
# ## 3 - Préparation

# %% [markdown]
# ### 3.1 - Suppression des variables inutiles

# %%
del data_3_months_fe
del data_6_months_fe
del data_9_months_fe
del data_12_months_fe
del data_15_months_fe
del data_18_months_fe
del data_all_fe
del client

# %% [markdown]
# ### 3.2 - Import des jeux de donnée après features engineering

# %%
data_3_months = pd.read_csv(
    "data/fe/data_3_months.csv", index_col="customer_unique_id")
data_6_months = pd.read_csv(
    "data/fe/data_6_months.csv", index_col="customer_unique_id")
data_9_months = pd.read_csv(
    "data/fe/data_9_months.csv", index_col="customer_unique_id")
data_12_months = pd.read_csv(
    "data/fe/data_12_months.csv", index_col="customer_unique_id")
data_15_months = pd.read_csv(
    "data/fe/data_15_months.csv", index_col="customer_unique_id")
data_18_months = pd.read_csv(
    "data/fe/data_18_months.csv", index_col="customer_unique_id")
data_all = pd.read_csv("data/fe/data_all.csv", index_col="customer_unique_id")

# %% [markdown]
# ### 3.3 - Normalisation

# %%
standardize = preprocessing.StandardScaler()
standardize.fit(data_3_months.iloc[:])
data_3_months = standardize.transform(data_3_months.iloc[:])

# %% [markdown]
# ### 3.4 - Déclaration des fonctions

# %%
def best_cluster_kmean(data, title):
    """Test the best number of cluster based on
        silhouette score from 2 to 25 with KMean algorithm.

        This function display a plot with silhouette score / # of cluster
    """
    km_cluster_number = []
    km_score = []
    for n in range(2, 25):
        kmean = KMeans(n_clusters=n, n_init=100, max_iter=3000, random_state=0)
        kmean.fit(data)
        km_cluster_number.append(n)
        km_score.append(silhouette_score(
            data, kmean.labels_, metric='euclidean'))
    plt.figure(figsize=(10, 5))
    plt.plot(km_cluster_number, km_score, color="skyblue", lw=2)
    plt.xlabel("Nombre de cluster")
    plt.ylabel("Score de silhouette")
    plt.title("{} Kmean".format(title))
    plt.tight_layout()
    plt.show()


def best_cluster_hier(data, title):
    """Test the best number of cluster based on
        silhouette score from 2 to 25 with Hierarchic Clustering algorithm.

        This function display a plot with silhouette score / # of cluster
    """
    hier_cluster_number = []
    hier_score = []
    for n in range(2, 25):
        clust_hier = AgglomerativeClustering(n_clusters=n)
        clust_hier.fit(data)
        hier_cluster_number.append(n)
        hier_score.append(silhouette_score(
            data, clust_hier.labels_, metric="euclidean"))
    plt.figure(figsize=(10, 5))
    plt.plot(hier_cluster_number, hier_score, color="skyblue", lw=2)
    plt.xlabel("Nombre de cluster")
    plt.ylabel("Score de silhouette")
    plt.title("{} Clustering Hierarchique".format(title))
    plt.tight_layout()
    plt.show()


def kmean_labels(n_clusters, fit_var):
    """This function return the predicted labels for 
        a number of cluster
    """
    kmean = KMeans(n_clusters=n_clusters, n_init=100,
                   max_iter=3000, random_state=0)
    kmean.fit(fit_var)
    return kmean.labels_


def kpca_projected(n_components, fit_var):
    """This function return the projected value after a KernelPCA decomposition"""
    kpca = decomposition.KernelPCA(
        n_components=n_components, kernel="cosine", random_state=0)
    return kpca.fit_transform(fit_var)


def isomap_projected(fit_var):
    """This function return the projected value after a ISOMap manifold"""
    isomap = manifold.Isomap(n_components=2, n_jobs=-1)
    return isomap.fit_transform(fit_var)


def tsne_projected(fit_var):
    """This function return the projected value after a TSNE manifold"""
    tsne = manifold.TSNE(n_components=2, perplexity=70, random_state=0, verbose=3)
    return tsne.fit_transform(fit_var)


def pca_projected(n_components, fit_var):
    """This function return the projected value after a PCA decomposition"""
    pca = decomposition.PCA(n_components=n_components, random_state=0)
    return pca.fit_transform(fit_var)


def mds_projected(fit_var):
    """This function return the projected value after a MDS manifold"""
    mds = manifold.MDS(n_components=2, random_state=0)
    return mds.fit_transform(fit_var)


def plot_with_tsne(fit_var, labels):
    """This function display a TSNE visualisation"""
    tsne = manifold.TSNE(n_components=2, perplexity=70, random_state=0)
    X_tsne = tsne.fit_transform(fit_var)
    plt.figure(figsize=(10, 5))
    plt.scatter(X_tsne[:, 0], X_tsne[:, 1], marker='.',
                c=labels, cmap=plt.get_cmap("tab20"))
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 4 - Clustering

# %% [markdown]
# ### 4.1 - K-means (Baseline)

# %%
best_cluster_kmean(data_3_months, "Baseline")

# %% [markdown]
# ### 4.2 - DBSCAN (Baseline)

# %%
dbscan_clust = DBSCAN(eps=0.8, min_samples=10)
dbscan_clust.fit(data_3_months)
# Out:
# DBSCAN(algorithm='auto', eps=0.8, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=10, n_jobs=None, p=None)

# %%
dbscan_labels = dbscan_clust.labels_

# %%
n_clusters = len(set(dbscan_labels)) - (1 if -1 in dbscan_labels else 0)
n_clusters
# Out:
# 19

# %%
silhouette_score(data_3_months, dbscan_labels)
# Out:
# -0.35095667658863056

# %%
list(dbscan_labels).count(-1)
# Out:
# 4506

# %%
del dbscan_clust
del dbscan_labels
del n_clusters

# %% [markdown]
# ### 4.3 - Clustering Hierarchique (Baseline)

# %%
best_cluster_hier(data_3_months, "Baseline")

# %% [markdown]
# ## 5- Réduction de dimension

# %%
X = data_3_months.values

# %% [markdown]
# ### 5.1 - Linear PCA
# #### 5.1.1 - Decomposition et projection

# %%
pca = decomposition.PCA(n_components=94)
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=94, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
components = range(1, len(pca.explained_variance_ratio_) + 1)
plt.figure(figsize=(10, 5))
plt.plot(components, pca.explained_variance_ratio_*100, color='skyblue', lw=2)
plt.xlabel('Nombre de composantes', fontsize=12)
plt.ylabel('Pourcentage Variance Expliquée', fontsize=12)
plt.title('PCA - part de variance expliquée par composantes')
plt.tight_layout()
plt.show()

# %%
X_pca_projected = pca_projected(10, X)

# %% [markdown]
# #### 5.1.2 - Clustering
# ##### 5.1.2.1 - K-means

# %%
best_cluster_kmean(X_pca_projected, "PCA")

# %% [markdown]
# ##### 5.1.2.2 - Clustering Hierarchique

# %%
best_cluster_hier(X_pca_projected, "PCA")

# %%
del pca
del X_pca_projected
del components

# %% [markdown]
# ### 5.2 -  Kernel PCA
# #### 5.2.1 - Decomposition et projection

# %%
kpca = decomposition.KernelPCA(n_components=X.shape[1], kernel="cosine")
kpca.fit(X)
# Out:
# KernelPCA(alpha=1.0, coef0=1, copy_X=True, degree=3, eigen_solver='auto',
#           fit_inverse_transform=False, gamma=None, kernel='cosine',
#           kernel_params=None, max_iter=None, n_components=101, n_jobs=None,
#           random_state=None, remove_zero_eig=False, tol=0)

# %%
components = range(1, len(kpca.lambdas_)+1)
plt.figure(figsize=(10, 5))
plt.plot(components, kpca.lambdas_*100, color='skyblue', lw=2)
plt.xlabel('Nombre de composantes', fontsize=12)
plt.ylabel('AgainValues', fontsize=12)
plt.title('KernelPCA - part de variance expliquée par composantes')
plt.tight_layout()
plt.show()

# %%
X_kpca_projected = kpca_projected(10, X)

# %% [markdown]
# #### 5.2.2 - Clustering
# ##### 5.2.2.1 - K-means

# %%
best_cluster_kmean(X_kpca_projected, "KernelPCA")

# %% [markdown]
# ##### 5.2.2.2 - Clustering Hierarchique

# %%
best_cluster_hier(X_kpca_projected, "KernelPCA")

# %%
del kpca
del X_kpca_projected
del components

# %% [markdown]
# ### 5.3 - T-SNE
# #### 5.3.1 - Decomposition et projection

# %%
X_tsne = tsne_projected(X)
# Out:
# [t-SNE] Computing 211 nearest neighbors...
# [t-SNE] Indexed 4876 samples in 0.062s...
# [t-SNE] Computed neighbors for 4876 samples in 3.948s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 4876
# [t-SNE] Computed conditional probabilities for sample 2000 / 4876
# [t-SNE] Computed conditional probabilities for sample 3000 / 4876
# [t-SNE] Computed conditional probabilities for sample 4000 / 4876
# [t-SNE] Computed conditional probabilities for sample 4876 / 4876
# [t-SNE] Mean sigma: 2.142806
# [t-SNE] Computed conditional probabilities in 0.429s
# [t-SNE] Iteration 50: error = 78.2091827, gradient norm = 0.0017460 (50 iterations in 3.211s)
# [t-SNE] Iteration 100: error = 76.7722473, gradient norm = 0.0025749 (50 iterations in 2.118s)
# [t-SNE] Iteration 150: error = 76.3736572, gradient norm = 0.0004908 (50 iterations in 1.802s)
# [t-SNE] Iteration 200: error = 76.3539276, gradient norm = 0.0002245 (50 iterations in 1.818s)
# [t-SNE] Iteration 250: error = 76.3492432, gradient norm = 0.0002127 (50 iterations in 1.853s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 76.349243
# [t-SNE] Iteration 300: error = 1.3935877, gradient norm = 0.0011993 (50 iterations in 1.659s)
# [t-SNE] Iteration 350: error = 1.0584505, gradient norm = 0.0004678 (50 iterations in 1.585s)
# [t-SNE] Iteration 400: error = 0.9379094, gradient norm = 0.0002376 (50 iterations in 1.701s)
# [t-SNE] Iteration 450: error = 0.8799012, gradient norm = 0.0001669 (50 iterations in 1.587s)
# [t-SNE] Iteration 500: error = 0.8476768, gradient norm = 0.0001195 (50 iterations in 1.587s)
# [t-SNE] Iteration 550: error = 0.8294214, gradient norm = 0.0000971 (50 iterations in 1.596s)
# [t-SNE] Iteration 600: error = 0.8188757, gradient norm = 0.0001074 (50 iterations in 1.607s)
# [t-SNE] Iteration 650: error = 0.8121947, gradient norm = 0.0000804 (50 iterations in 1.604s)
# [t-SNE] Iteration 700: error = 0.8082157, gradient norm = 0.0000697 (50 iterations in 1.604s)
# [t-SNE] Iteration 750: error = 0.8051608, gradient norm = 0.0000653 (50 iterations in 1.754s)
# [t-SNE] Iteration 800: error = 0.8028879, gradient norm = 0.0000687 (50 iterations in 1.617s)
# [t-SNE] Iteration 850: error = 0.8007923, gradient norm = 0.0000726 (50 iterations in 1.619s)
# [t-SNE] Iteration 900: error = 0.7994170, gradient norm = 0.0000675 (50 iterations in 1.623s)
# [t-SNE] Iteration 950: error = 0.7983970, gradient norm = 0.0000705 (50 iterations in 1.897s)
# [t-SNE] Iteration 1000: error = 0.7976195, gradient norm = 0.0000663 (50 iterations in 1.967s)
# [t-SNE] KL divergence after 1000 iterations: 0.797620

# %%
plt.figure(figsize=(10, 5))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], s=0.5)
plt.xlim(-75, 75)
plt.ylim(-75, 75)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 5.3.2 - Clustering
# ##### 5.3.2.1 - K-means

# %%
best_cluster_kmean(X_tsne, "TSNE")

# %% [markdown]
# ##### 5.3.2.2 - Clustering Hierarchique

# %%
best_cluster_hier(X_tsne, "TSNE")

# %%
del X_tsne

# %% [markdown]
# ### 5.4 - MDS
# #### 5.4.1 - Decomposition et projection

# %%
X_mds = mds_projected(X)

# %% [markdown]
# #### 5.4.2 - Clustering
# ##### 5.4.2.1 - K-means

# %%
best_cluster_kmean(X_mds, "MDS")

# %% [markdown]
# ##### 5.4.2.2 - Clustering Hierarchique

# %%
best_cluster_hier(X_mds, "MDS")

# %%
del X_mds

# %% [markdown]
# ### 5.5 - ISO Map
# #### 5.5.1 - Decomposition et projection

# %%
X_isomap = isomap_projected(X)

# %% [markdown]
# #### 5.5.2 - Clustering
# ##### 5.5.2.1 - K-means

# %%
best_cluster_kmean(X_isomap, "ISOMap")

# %% [markdown]
# ##### 5.5.2.2 - Clustering Hierarchique

# %%
best_cluster_hier(X_isomap, "ISOMap")

# %%
del X_isomap

# %% [markdown]
# ### 5.6 - Suppression des variables inutiles

# %%
del standardize

# %% [markdown]
# ## 6 - Choix du meilleur modèle

# %% [markdown]
# ### 6.1 - KernelPCA (10 composantes) puis KMeans avec 11 Clusters

# %%
X_kpca_projected = kpca_projected(10, X)

# %%
data_3_months['cluster_kpca_km'] = kmean_labels(11, X_kpca_projected)

# %%
plt.figure(figsize=(10, 5))
plt.hist(data_3_months['cluster_kpca_km'], bins=11)
plt.tight_layout()
plt.show()

# %%
print('taille cluster max: {}'.format(
    max(data_3_months.groupby(['cluster_kpca_km']).size())))
print('taille cluster min: {}'.format(
    min(data_3_months.groupby(['cluster_kpca_km']).size())))
# Out:
# taille cluster max: 1374
# taille cluster min: 212

# %%
plot_with_tsne(X_kpca_projected, data_3_months["cluster_kpca_km"])

# %%
del X_kpca_projected

# %% [markdown]
# ### 6.2 - ISOMap (2 composantes) puis KMeans avec 6 Clusters

# %%
X_isomap = isomap_projected(X)

# %%
data_3_months['cluster_iso_km'] = kmean_labels(6, X_isomap)

# %%
plt.figure(figsize=(10, 5))
plt.hist(data_3_months['cluster_iso_km'], bins=6)
plt.tight_layout()
plt.show()

# %%
print('taille cluster max: {}'.format(
    max(data_3_months.groupby(['cluster_iso_km']).size())))
print('taille cluster min: {}'.format(
    min(data_3_months.groupby(['cluster_iso_km']).size())))
# Out:
# taille cluster max: 3205
# taille cluster min: 92

# %%
plot_with_tsne(X_isomap, data_3_months["cluster_iso_km"])

# %%
del X_isomap

# %% [markdown]
# ### 6.3 - TSNE (2 composantes) puis KMeans avec 17 Clusters

# %%
X_tsne = tsne_projected(X)
# Out:
# [t-SNE] Computing 211 nearest neighbors...
# [t-SNE] Indexed 4876 samples in 0.058s...
# [t-SNE] Computed neighbors for 4876 samples in 4.054s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 4876
# [t-SNE] Computed conditional probabilities for sample 2000 / 4876
# [t-SNE] Computed conditional probabilities for sample 3000 / 4876
# [t-SNE] Computed conditional probabilities for sample 4000 / 4876
# [t-SNE] Computed conditional probabilities for sample 4876 / 4876
# [t-SNE] Mean sigma: 2.142806
# [t-SNE] Computed conditional probabilities in 0.599s
# [t-SNE] Iteration 50: error = 78.2091827, gradient norm = 0.0017460 (50 iterations in 2.494s)
# [t-SNE] Iteration 100: error = 76.7722473, gradient norm = 0.0025749 (50 iterations in 1.875s)
# [t-SNE] Iteration 150: error = 76.3736572, gradient norm = 0.0004908 (50 iterations in 1.822s)
# [t-SNE] Iteration 200: error = 76.3539276, gradient norm = 0.0002245 (50 iterations in 1.992s)
# [t-SNE] Iteration 250: error = 76.3492432, gradient norm = 0.0002127 (50 iterations in 1.813s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 76.349243
# [t-SNE] Iteration 300: error = 1.3935877, gradient norm = 0.0011993 (50 iterations in 1.619s)
# [t-SNE] Iteration 350: error = 1.0584506, gradient norm = 0.0004678 (50 iterations in 1.526s)
# [t-SNE] Iteration 400: error = 0.9379094, gradient norm = 0.0002376 (50 iterations in 1.546s)
# [t-SNE] Iteration 450: error = 0.8799012, gradient norm = 0.0001669 (50 iterations in 1.551s)
# [t-SNE] Iteration 500: error = 0.8476768, gradient norm = 0.0001195 (50 iterations in 1.678s)
# [t-SNE] Iteration 550: error = 0.8294215, gradient norm = 0.0000971 (50 iterations in 1.580s)
# [t-SNE] Iteration 600: error = 0.8188757, gradient norm = 0.0001074 (50 iterations in 1.553s)
# [t-SNE] Iteration 650: error = 0.8121947, gradient norm = 0.0000804 (50 iterations in 2.557s)
# [t-SNE] Iteration 700: error = 0.8082157, gradient norm = 0.0000697 (50 iterations in 2.148s)
# [t-SNE] Iteration 750: error = 0.8051608, gradient norm = 0.0000653 (50 iterations in 1.622s)
# [t-SNE] Iteration 800: error = 0.8028879, gradient norm = 0.0000687 (50 iterations in 1.709s)
# [t-SNE] Iteration 850: error = 0.8007923, gradient norm = 0.0000726 (50 iterations in 1.570s)
# [t-SNE] Iteration 900: error = 0.7994170, gradient norm = 0.0000675 (50 iterations in 1.566s)
# [t-SNE] Iteration 950: error = 0.7983971, gradient norm = 0.0000705 (50 iterations in 1.562s)
# [t-SNE] Iteration 1000: error = 0.7976195, gradient norm = 0.0000663 (50 iterations in 1.562s)
# [t-SNE] KL divergence after 1000 iterations: 0.797620

# %%
data_3_months['cluster_tsne_km'] = kmean_labels(17, X_tsne)

# %%
plt.figure(figsize=(10, 5))
plt.hist(data_3_months['cluster_tsne_km'], bins=17)
plt.tight_layout()
plt.show()

# %%
print('taille cluster max: {}'.format(
    max(data_3_months.groupby(['cluster_tsne_km']).size())))
print('taille cluster min: {}'.format(
    min(data_3_months.groupby(['cluster_tsne_km']).size())))
# Out:
# taille cluster max: 475
# taille cluster min: 120

# %%
plt.figure(figsize=(10, 5))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], marker='.',
            c=data_3_months['cluster_tsne_km'], cmap=plt.get_cmap("tab20"))
plt.xlim(-75, 75)
plt.ylim(-75, 75)
plt.tight_layout()
plt.show()

# %%
del X_tsne

# %% [markdown]
# ### 6.4 - PCA (50) + TSNE (2) avec KMeans (17 Clusters)

# %%
X_pca_projected = pca_projected(50, X)

# %%
X_tsne = tsne_projected(X_pca_projected)
# Out:
# [t-SNE] Computing 211 nearest neighbors...
# [t-SNE] Indexed 4876 samples in 0.012s...
# [t-SNE] Computed neighbors for 4876 samples in 2.497s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 4876
# [t-SNE] Computed conditional probabilities for sample 2000 / 4876
# [t-SNE] Computed conditional probabilities for sample 3000 / 4876
# [t-SNE] Computed conditional probabilities for sample 4000 / 4876
# [t-SNE] Computed conditional probabilities for sample 4876 / 4876
# [t-SNE] Mean sigma: 1.611578
# [t-SNE] Computed conditional probabilities in 0.339s
# [t-SNE] Iteration 50: error = 78.2695007, gradient norm = 0.0089790 (50 iterations in 3.311s)
# [t-SNE] Iteration 100: error = 78.0127716, gradient norm = 0.0415368 (50 iterations in 2.943s)
# [t-SNE] Iteration 150: error = 77.7993088, gradient norm = 0.0038149 (50 iterations in 2.409s)
# [t-SNE] Iteration 200: error = 77.7530060, gradient norm = 0.0151023 (50 iterations in 3.029s)
# [t-SNE] Iteration 250: error = 77.7006989, gradient norm = 0.0341870 (50 iterations in 3.452s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 77.700699
# [t-SNE] Iteration 300: error = 1.5125974, gradient norm = 0.0012377 (50 iterations in 1.963s)
# [t-SNE] Iteration 350: error = 1.1829312, gradient norm = 0.0004463 (50 iterations in 1.785s)
# [t-SNE] Iteration 400: error = 1.0630159, gradient norm = 0.0002397 (50 iterations in 1.639s)
# [t-SNE] Iteration 450: error = 1.0049298, gradient norm = 0.0001878 (50 iterations in 1.633s)
# [t-SNE] Iteration 500: error = 0.9717608, gradient norm = 0.0001348 (50 iterations in 1.595s)
# [t-SNE] Iteration 550: error = 0.9528473, gradient norm = 0.0001119 (50 iterations in 1.596s)
# [t-SNE] Iteration 600: error = 0.9428524, gradient norm = 0.0000932 (50 iterations in 1.597s)
# [t-SNE] Iteration 650: error = 0.9374000, gradient norm = 0.0000764 (50 iterations in 1.754s)
# [t-SNE] Iteration 700: error = 0.9337465, gradient norm = 0.0000735 (50 iterations in 1.613s)
# [t-SNE] Iteration 750: error = 0.9308305, gradient norm = 0.0000678 (50 iterations in 1.629s)
# [t-SNE] Iteration 800: error = 0.9283851, gradient norm = 0.0000724 (50 iterations in 1.657s)
# [t-SNE] Iteration 850: error = 0.9263876, gradient norm = 0.0000704 (50 iterations in 1.637s)
# [t-SNE] Iteration 900: error = 0.9248415, gradient norm = 0.0000615 (50 iterations in 1.633s)
# [t-SNE] Iteration 950: error = 0.9238613, gradient norm = 0.0000595 (50 iterations in 1.646s)
# [t-SNE] Iteration 1000: error = 0.9227313, gradient norm = 0.0000558 (50 iterations in 1.808s)
# [t-SNE] KL divergence after 1000 iterations: 0.922731

# %%
data_3_months['cluster_pca_tsne_km'] = kmean_labels(17, X_tsne)

# %%
plt.figure(figsize=(10, 5))
plt.hist(data_3_months['cluster_pca_tsne_km'], bins=17)
plt.tight_layout()
plt.show()

# %%
print('taille cluster max: {}'.format(
    max(data_3_months.groupby(['cluster_pca_tsne_km']).size())))
print('taille cluster min: {}'.format(
    min(data_3_months.groupby(['cluster_pca_tsne_km']).size())))
# Out:
# taille cluster max: 430
# taille cluster min: 127

# %%
plt.figure(figsize=(10, 5))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], marker='.',
            c=data_3_months['cluster_pca_tsne_km'], cmap=plt.get_cmap("tab20"))
plt.xlim(-75, 75)
plt.ylim(-75, 75)
plt.tight_layout()
plt.show()

# %%
del X_pca_projected
del X_tsne

# %% [markdown]
# La réduction de dimension TSNE est très efficace, le fait de passer par une autre réduction de dimension avant TSNE ne fait change pas grand chose du coup, on passera seulement par du TSNE classique.

# %%
data_3_months = data_3_months.drop(
    columns=["cluster_iso_km", "cluster_pca_tsne_km", "cluster_kpca_km"])

# %%
def radar_plot():
    from math import pi
    categories = ["recency", "frequency", "monetary",
                  "payment_value_mean", "review_score_mean"]
    values = data_3_months[categories].mean().values.flatten().tolist()
    values += values[:1]

    angles = [n / float(len(categories)) * 2 *
              pi for n in range(len(categories))]
    angles += angles[:1]

    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(
        10, 5), subplot_kw=(dict(polar=True)))

    plt.xticks(angles[:-1], categories, color='grey', size=12)
    plt.yticks(np.arange(1, 6), ["1", "2", "3",
                                 "4", "5"], color='grey', size=12)
    ax.set_rlabel_position(30)
    color_rad = ["skyblue", "red", "green", "magenta", "orange"]

    for i, idx in enumerate(data_3_months["cluster_tsne_km"].value_counts().nlargest(2).index):
        val = data_3_months.groupby(
            "cluster_tsne_km").mean().loc[idx][categories].tolist()
        val += val[:1]
        ax.plot(angles, val, lw=1, ls='solid', label="Cluster {}".format(idx))
        ax.fill(angles, val, color_rad[i], alpha=0.2)

    plt.legend(loc='upper right')
    plt.tight_layout()
    plt.show()

# %%
radar_plot()

# %%
data_result = pd.DataFrame(index=data_all.index)

# %%
data_result['cluster_3_months'] = data_3_months['cluster_tsne_km']
data_result
# Out:
#                                   cluster_3_months
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2               NaN
# 0000b849f77a49e4a4ce2b2a4ca5be3f               NaN
# 0000f46a3911fa3c0805444483337064               2.0
# 0000f6ccb0745a6a4b88665a16c9f078               NaN
# 0004aac84e0df4da2b147fca70cf8255               NaN
# ...                                            ...
# fffcf5a5ff07b0908bd4e2dbc735a684               NaN
# fffea47cd6d3cc0a88bd621562a9d061               NaN
# ffff371b4d645b6ecea244b27531430a              14.0
# ffff5962728ec6157033ef9805bacc48               NaN
# ffffd2657e2aad2907e67c3e9daecbeb               NaN
#
# [93790 rows x 1 columns]

# %%
data_3_months.to_csv("data/results/data_3_months.csv")

# %%
del X
del data_3_months

# %% [markdown]
# ## 7 - Clustering sur les autres jeux de données
# ### 7.1 - Normalisation

# %%
standardize = preprocessing.StandardScaler(
    copy=True, with_mean=True, with_std=True)

# %%
standardize.fit(data_6_months.iloc[:])
data_6_months = standardize.transform(data_6_months.iloc[:])

# %%
standardize.fit(data_9_months.iloc[:])
data_9_months = standardize.transform(data_9_months.iloc[:])

# %%
standardize.fit(data_12_months.iloc[:])
data_12_months = standardize.transform(data_12_months.iloc[:])

# %%
standardize.fit(data_15_months.iloc[:])
data_15_months = standardize.transform(data_15_months.iloc[:])

# %%
standardize.fit(data_18_months.iloc[:])
data_18_months = standardize.transform(data_18_months.iloc[:])

# %%
standardize.fit(data_all.iloc[:])
data_all = standardize.transform(data_all.iloc[:])

# %% [markdown]
# ### 7.2 - Réduction de dimension

# %%
X_6 = data_6_months.values
X_9 = data_9_months.values
X_12 = data_12_months.values
X_15 = data_15_months.values
X_18 = data_18_months.values
X_all = data_all.values

# %% [markdown]
# #### 7.2.1 - 6 mois

# %%
X_tsne = tsne_projected(X_6)
# Out:
# [t-SNE] Computing 211 nearest neighbors...
# [t-SNE] Indexed 13671 samples in 0.418s...
# [t-SNE] Computed neighbors for 13671 samples in 25.534s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 13671
# [t-SNE] Computed conditional probabilities for sample 2000 / 13671
# [t-SNE] Computed conditional probabilities for sample 3000 / 13671
# [t-SNE] Computed conditional probabilities for sample 4000 / 13671
# [t-SNE] Computed conditional probabilities for sample 5000 / 13671
# [t-SNE] Computed conditional probabilities for sample 6000 / 13671
# [t-SNE] Computed conditional probabilities for sample 7000 / 13671
# [t-SNE] Computed conditional probabilities for sample 8000 / 13671
# [t-SNE] Computed conditional probabilities for sample 9000 / 13671
# [t-SNE] Computed conditional probabilities for sample 10000 / 13671
# [t-SNE] Computed conditional probabilities for sample 11000 / 13671
# [t-SNE] Computed conditional probabilities for sample 12000 / 13671
# [t-SNE] Computed conditional probabilities for sample 13000 / 13671
# [t-SNE] Computed conditional probabilities for sample 13671 / 13671
# [t-SNE] Mean sigma: 1.743064
# [t-SNE] Computed conditional probabilities in 0.971s
# [t-SNE] Iteration 50: error = 90.6171875, gradient norm = 0.0050077 (50 iterations in 6.779s)
# [t-SNE] Iteration 100: error = 77.3215103, gradient norm = 0.0022977 (50 iterations in 5.769s)
# [t-SNE] Iteration 150: error = 73.9334488, gradient norm = 0.0010988 (50 iterations in 5.507s)
# [t-SNE] Iteration 200: error = 72.5312729, gradient norm = 0.0007178 (50 iterations in 6.190s)
# [t-SNE] Iteration 250: error = 71.7424469, gradient norm = 0.0004897 (50 iterations in 5.684s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 71.742447
# [t-SNE] Iteration 300: error = 2.2231491, gradient norm = 0.0013679 (50 iterations in 5.798s)
# [t-SNE] Iteration 350: error = 1.5949445, gradient norm = 0.0006248 (50 iterations in 5.343s)
# [t-SNE] Iteration 400: error = 1.3000252, gradient norm = 0.0003728 (50 iterations in 5.334s)
# [t-SNE] Iteration 450: error = 1.1307173, gradient norm = 0.0002533 (50 iterations in 5.733s)
# [t-SNE] Iteration 500: error = 1.0220523, gradient norm = 0.0001847 (50 iterations in 6.298s)
# [t-SNE] Iteration 550: error = 0.9468106, gradient norm = 0.0001429 (50 iterations in 6.863s)
# [t-SNE] Iteration 600: error = 0.8918123, gradient norm = 0.0001159 (50 iterations in 5.623s)
# [t-SNE] Iteration 650: error = 0.8498676, gradient norm = 0.0000972 (50 iterations in 5.289s)
# [t-SNE] Iteration 700: error = 0.8174643, gradient norm = 0.0000825 (50 iterations in 5.177s)
# [t-SNE] Iteration 750: error = 0.7919347, gradient norm = 0.0000717 (50 iterations in 5.121s)
# [t-SNE] Iteration 800: error = 0.7714327, gradient norm = 0.0000632 (50 iterations in 5.361s)
# [t-SNE] Iteration 850: error = 0.7548221, gradient norm = 0.0000599 (50 iterations in 5.215s)
# [t-SNE] Iteration 900: error = 0.7416985, gradient norm = 0.0000553 (50 iterations in 5.190s)
# [t-SNE] Iteration 950: error = 0.7315729, gradient norm = 0.0000530 (50 iterations in 5.130s)
# [t-SNE] Iteration 1000: error = 0.7240999, gradient norm = 0.0000503 (50 iterations in 5.220s)
# [t-SNE] KL divergence after 1000 iterations: 0.724100

# %%
best_cluster_kmean(X_tsne, "TSNE PCA")

# %%
data_6_months['cluster_tsne_km'] = kmean_labels(16, X_tsne)

# %%
data_6_months.to_csv("data/results/data_6_months.csv")

# %%
data_result['cluster_6_months'] = data_6_months['cluster_tsne_km']

# %%
del X_6
del X_tsne
del data_6_months

# %% [markdown]
# #### 7.2.2 - 9 mois

# %%
X_tsne = tsne_projected(X_9)
# Out:
# [t-SNE] Computing 211 nearest neighbors...
# [t-SNE] Indexed 25575 samples in 1.305s...
# [t-SNE] Computed neighbors for 25575 samples in 109.230s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 25575
# [t-SNE] Computed conditional probabilities for sample 2000 / 25575
# [t-SNE] Computed conditional probabilities for sample 3000 / 25575
# [t-SNE] Computed conditional probabilities for sample 4000 / 25575
# [t-SNE] Computed conditional probabilities for sample 5000 / 25575
# [t-SNE] Computed conditional probabilities for sample 6000 / 25575
# [t-SNE] Computed conditional probabilities for sample 7000 / 25575
# [t-SNE] Computed conditional probabilities for sample 8000 / 25575
# [t-SNE] Computed conditional probabilities for sample 9000 / 25575
# [t-SNE] Computed conditional probabilities for sample 10000 / 25575
# [t-SNE] Computed conditional probabilities for sample 11000 / 25575
# [t-SNE] Computed conditional probabilities for sample 12000 / 25575
# [t-SNE] Computed conditional probabilities for sample 13000 / 25575
# [t-SNE] Computed conditional probabilities for sample 14000 / 25575
# [t-SNE] Computed conditional probabilities for sample 15000 / 25575
# [t-SNE] Computed conditional probabilities for sample 16000 / 25575
# [t-SNE] Computed conditional probabilities for sample 17000 / 25575
# [t-SNE] Computed conditional probabilities for sample 18000 / 25575
# [t-SNE] Computed conditional probabilities for sample 19000 / 25575
# [t-SNE] Computed conditional probabilities for sample 20000 / 25575
# [t-SNE] Computed conditional probabilities for sample 21000 / 25575
# [t-SNE] Computed conditional probabilities for sample 22000 / 25575
# [t-SNE] Computed conditional probabilities for sample 23000 / 25575
# [t-SNE] Computed conditional probabilities for sample 24000 / 25575
# [t-SNE] Computed conditional probabilities for sample 25000 / 25575
# [t-SNE] Computed conditional probabilities for sample 25575 / 25575
# [t-SNE] Mean sigma: 1.331245
# [t-SNE] Computed conditional probabilities in 1.816s
# [t-SNE] Iteration 50: error = 98.5031204, gradient norm = 0.0001996 (50 iterations in 19.177s)
# [t-SNE] Iteration 100: error = 81.2234344, gradient norm = 0.0028037 (50 iterations in 14.524s)
# [t-SNE] Iteration 150: error = 74.7338715, gradient norm = 0.0013851 (50 iterations in 11.189s)
# [t-SNE] Iteration 200: error = 71.9779968, gradient norm = 0.0009481 (50 iterations in 11.089s)
# [t-SNE] Iteration 250: error = 70.3791962, gradient norm = 0.0007252 (50 iterations in 11.268s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.379196
# [t-SNE] Iteration 300: error = 2.7940040, gradient norm = 0.0012192 (50 iterations in 11.005s)
# [t-SNE] Iteration 350: error = 2.1979218, gradient norm = 0.0006882 (50 iterations in 10.613s)
# [t-SNE] Iteration 400: error = 1.8149589, gradient norm = 0.0004452 (50 iterations in 10.554s)
# [t-SNE] Iteration 450: error = 1.5641153, gradient norm = 0.0003162 (50 iterations in 10.307s)
# [t-SNE] Iteration 500: error = 1.3903152, gradient norm = 0.0002388 (50 iterations in 10.253s)
# [t-SNE] Iteration 550: error = 1.2630203, gradient norm = 0.0001886 (50 iterations in 10.264s)
# [t-SNE] Iteration 600: error = 1.1660531, gradient norm = 0.0001537 (50 iterations in 10.268s)
# [t-SNE] Iteration 650: error = 1.0899954, gradient norm = 0.0001279 (50 iterations in 10.669s)
# [t-SNE] Iteration 700: error = 1.0289052, gradient norm = 0.0001089 (50 iterations in 11.580s)
# [t-SNE] Iteration 750: error = 0.9788294, gradient norm = 0.0000943 (50 iterations in 14.559s)
# [t-SNE] Iteration 800: error = 0.9370326, gradient norm = 0.0000828 (50 iterations in 16.795s)
# [t-SNE] Iteration 850: error = 0.9016821, gradient norm = 0.0000735 (50 iterations in 10.655s)
# [t-SNE] Iteration 900: error = 0.8714244, gradient norm = 0.0000661 (50 iterations in 10.210s)
# [t-SNE] Iteration 950: error = 0.8452924, gradient norm = 0.0000600 (50 iterations in 10.209s)
# [t-SNE] Iteration 1000: error = 0.8226975, gradient norm = 0.0000542 (50 iterations in 10.469s)
# [t-SNE] KL divergence after 1000 iterations: 0.822698

# %%
best_cluster_kmean(X_tsne, "TSNE PCA")

# %%
data_9_months['cluster_tsne_km'] = kmean_labels(17, X_tsne)

# %%
data_9_months.to_csv("data/results/data_9_months.csv")

# %%
data_result['cluster_9_months'] = data_9_months['cluster_tsne_km']

# %%
del X_9
del X_tsne
del data_9_months

# %% [markdown]
# #### 7.2.3 - 12 mois

# %%
X_tsne = tsne_projected(X_12)
# Out:
# [t-SNE] Computing 211 nearest neighbors...
# [t-SNE] Indexed 42403 samples in 6.659s...
# [t-SNE] Computed neighbors for 42403 samples in 285.562s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 42403
# [t-SNE] Computed conditional probabilities for sample 2000 / 42403
# [t-SNE] Computed conditional probabilities for sample 3000 / 42403
# [t-SNE] Computed conditional probabilities for sample 4000 / 42403
# [t-SNE] Computed conditional probabilities for sample 5000 / 42403
# [t-SNE] Computed conditional probabilities for sample 6000 / 42403
# [t-SNE] Computed conditional probabilities for sample 7000 / 42403
# [t-SNE] Computed conditional probabilities for sample 8000 / 42403
# [t-SNE] Computed conditional probabilities for sample 9000 / 42403
# [t-SNE] Computed conditional probabilities for sample 10000 / 42403
# [t-SNE] Computed conditional probabilities for sample 11000 / 42403
# [t-SNE] Computed conditional probabilities for sample 12000 / 42403
# [t-SNE] Computed conditional probabilities for sample 13000 / 42403
# [t-SNE] Computed conditional probabilities for sample 14000 / 42403
# [t-SNE] Computed conditional probabilities for sample 15000 / 42403
# [t-SNE] Computed conditional probabilities for sample 16000 / 42403
# [t-SNE] Computed conditional probabilities for sample 17000 / 42403
# [t-SNE] Computed conditional probabilities for sample 18000 / 42403
# [t-SNE] Computed conditional probabilities for sample 19000 / 42403
# [t-SNE] Computed conditional probabilities for sample 20000 / 42403
# [t-SNE] Computed conditional probabilities for sample 21000 / 42403
# [t-SNE] Computed conditional probabilities for sample 22000 / 42403
# [t-SNE] Computed conditional probabilities for sample 23000 / 42403
# [t-SNE] Computed conditional probabilities for sample 24000 / 42403
# [t-SNE] Computed conditional probabilities for sample 25000 / 42403
# [t-SNE] Computed conditional probabilities for sample 26000 / 42403
# [t-SNE] Computed conditional probabilities for sample 27000 / 42403
# [t-SNE] Computed conditional probabilities for sample 28000 / 42403
# [t-SNE] Computed conditional probabilities for sample 29000 / 42403
# [t-SNE] Computed conditional probabilities for sample 30000 / 42403
# [t-SNE] Computed conditional probabilities for sample 31000 / 42403
# [t-SNE] Computed conditional probabilities for sample 32000 / 42403
# [t-SNE] Computed conditional probabilities for sample 33000 / 42403
# [t-SNE] Computed conditional probabilities for sample 34000 / 42403
# [t-SNE] Computed conditional probabilities for sample 35000 / 42403
# [t-SNE] Computed conditional probabilities for sample 36000 / 42403
# [t-SNE] Computed conditional probabilities for sample 37000 / 42403
# [t-SNE] Computed conditional probabilities for sample 38000 / 42403
# [t-SNE] Computed conditional probabilities for sample 39000 / 42403
# [t-SNE] Computed conditional probabilities for sample 40000 / 42403
# [t-SNE] Computed conditional probabilities for sample 41000 / 42403
# [t-SNE] Computed conditional probabilities for sample 42000 / 42403
# [t-SNE] Computed conditional probabilities for sample 42403 / 42403
# [t-SNE] Mean sigma: 1.051320
# [t-SNE] Computed conditional probabilities in 3.470s
# [t-SNE] Iteration 50: error = 104.3480225, gradient norm = 0.0000359 (50 iterations in 37.296s)
# [t-SNE] Iteration 100: error = 87.1542511, gradient norm = 0.0025544 (50 iterations in 27.746s)
# [t-SNE] Iteration 150: error = 78.1989059, gradient norm = 0.0013559 (50 iterations in 20.861s)
# [t-SNE] Iteration 200: error = 74.5736389, gradient norm = 0.0009250 (50 iterations in 20.790s)
# [t-SNE] Iteration 250: error = 72.4556046, gradient norm = 0.0007159 (50 iterations in 20.236s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.455605
# [t-SNE] Iteration 300: error = 3.2226515, gradient norm = 0.0010123 (50 iterations in 19.444s)
# [t-SNE] Iteration 350: error = 2.7520134, gradient norm = 0.0006859 (50 iterations in 20.811s)
# [t-SNE] Iteration 400: error = 2.3606365, gradient norm = 0.0004781 (50 iterations in 18.176s)
# [t-SNE] Iteration 450: error = 2.0658119, gradient norm = 0.0003546 (50 iterations in 20.898s)
# [t-SNE] Iteration 500: error = 1.8422439, gradient norm = 0.0002763 (50 iterations in 18.346s)
# [t-SNE] Iteration 550: error = 1.6704091, gradient norm = 0.0002223 (50 iterations in 18.872s)
# [t-SNE] Iteration 600: error = 1.5349544, gradient norm = 0.0001841 (50 iterations in 17.785s)
# [t-SNE] Iteration 650: error = 1.4250903, gradient norm = 0.0001560 (50 iterations in 17.846s)
# [t-SNE] Iteration 700: error = 1.3343608, gradient norm = 0.0001339 (50 iterations in 17.832s)
# [t-SNE] Iteration 750: error = 1.2585986, gradient norm = 0.0001164 (50 iterations in 17.652s)
# [t-SNE] Iteration 800: error = 1.1944506, gradient norm = 0.0001025 (50 iterations in 17.745s)
# [t-SNE] Iteration 850: error = 1.1393960, gradient norm = 0.0000913 (50 iterations in 18.280s)
# [t-SNE] Iteration 900: error = 1.0917933, gradient norm = 0.0000820 (50 iterations in 17.748s)
# [t-SNE] Iteration 950: error = 1.0501134, gradient norm = 0.0000740 (50 iterations in 21.024s)
# [t-SNE] Iteration 1000: error = 1.0134573, gradient norm = 0.0000673 (50 iterations in 27.625s)
# [t-SNE] KL divergence after 1000 iterations: 1.013457

# %%
best_cluster_kmean(X_tsne, "TSNE PCA")

# %%
data_12_months['cluster_tsne_km'] = kmean_labels(19, X_tsne)

# %%
data_12_months.to_csv("data/results/data_12_months.csv")

# %%
data_result['cluster_12_months'] = data_12_months['cluster_tsne_km']

# %%
del X_12
del X_tsne
del data_12_months

# %% [markdown]
# #### 7.2.4 - 15 mois

# %%
X_tsne = tsne_projected(X_15)
# Out:
# [t-SNE] Computing 211 nearest neighbors...
# [t-SNE] Indexed 62284 samples in 16.231s...
# [t-SNE] Computed neighbors for 62284 samples in 606.082s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 62284
# [t-SNE] Computed conditional probabilities for sample 2000 / 62284
# [t-SNE] Computed conditional probabilities for sample 3000 / 62284
# [t-SNE] Computed conditional probabilities for sample 4000 / 62284
# [t-SNE] Computed conditional probabilities for sample 5000 / 62284
# [t-SNE] Computed conditional probabilities for sample 6000 / 62284
# [t-SNE] Computed conditional probabilities for sample 7000 / 62284
# [t-SNE] Computed conditional probabilities for sample 8000 / 62284
# [t-SNE] Computed conditional probabilities for sample 9000 / 62284
# [t-SNE] Computed conditional probabilities for sample 10000 / 62284
# [t-SNE] Computed conditional probabilities for sample 11000 / 62284
# [t-SNE] Computed conditional probabilities for sample 12000 / 62284
# [t-SNE] Computed conditional probabilities for sample 13000 / 62284
# [t-SNE] Computed conditional probabilities for sample 14000 / 62284
# [t-SNE] Computed conditional probabilities for sample 15000 / 62284
# [t-SNE] Computed conditional probabilities for sample 16000 / 62284
# [t-SNE] Computed conditional probabilities for sample 17000 / 62284
# [t-SNE] Computed conditional probabilities for sample 18000 / 62284
# [t-SNE] Computed conditional probabilities for sample 19000 / 62284
# [t-SNE] Computed conditional probabilities for sample 20000 / 62284
# [t-SNE] Computed conditional probabilities for sample 21000 / 62284
# [t-SNE] Computed conditional probabilities for sample 22000 / 62284
# [t-SNE] Computed conditional probabilities for sample 23000 / 62284
# [t-SNE] Computed conditional probabilities for sample 24000 / 62284
# [t-SNE] Computed conditional probabilities for sample 25000 / 62284
# [t-SNE] Computed conditional probabilities for sample 26000 / 62284
# [t-SNE] Computed conditional probabilities for sample 27000 / 62284
# [t-SNE] Computed conditional probabilities for sample 28000 / 62284
# [t-SNE] Computed conditional probabilities for sample 29000 / 62284
# [t-SNE] Computed conditional probabilities for sample 30000 / 62284
# [t-SNE] Computed conditional probabilities for sample 31000 / 62284
# [t-SNE] Computed conditional probabilities for sample 32000 / 62284
# [t-SNE] Computed conditional probabilities for sample 33000 / 62284
# [t-SNE] Computed conditional probabilities for sample 34000 / 62284
# [t-SNE] Computed conditional probabilities for sample 35000 / 62284
# [t-SNE] Computed conditional probabilities for sample 36000 / 62284
# [t-SNE] Computed conditional probabilities for sample 37000 / 62284
# [t-SNE] Computed conditional probabilities for sample 38000 / 62284
# [t-SNE] Computed conditional probabilities for sample 39000 / 62284
# [t-SNE] Computed conditional probabilities for sample 40000 / 62284
# [t-SNE] Computed conditional probabilities for sample 41000 / 62284
# [t-SNE] Computed conditional probabilities for sample 42000 / 62284
# [t-SNE] Computed conditional probabilities for sample 43000 / 62284
# [t-SNE] Computed conditional probabilities for sample 44000 / 62284
# [t-SNE] Computed conditional probabilities for sample 45000 / 62284
# [t-SNE] Computed conditional probabilities for sample 46000 / 62284
# [t-SNE] Computed conditional probabilities for sample 47000 / 62284
# [t-SNE] Computed conditional probabilities for sample 48000 / 62284
# [t-SNE] Computed conditional probabilities for sample 49000 / 62284
# [t-SNE] Computed conditional probabilities for sample 50000 / 62284
# [t-SNE] Computed conditional probabilities for sample 51000 / 62284
# [t-SNE] Computed conditional probabilities for sample 52000 / 62284
# [t-SNE] Computed conditional probabilities for sample 53000 / 62284
# [t-SNE] Computed conditional probabilities for sample 54000 / 62284
# [t-SNE] Computed conditional probabilities for sample 55000 / 62284
# [t-SNE] Computed conditional probabilities for sample 56000 / 62284
# [t-SNE] Computed conditional probabilities for sample 57000 / 62284
# [t-SNE] Computed conditional probabilities for sample 58000 / 62284
# [t-SNE] Computed conditional probabilities for sample 59000 / 62284
# [t-SNE] Computed conditional probabilities for sample 60000 / 62284
# [t-SNE] Computed conditional probabilities for sample 61000 / 62284
# [t-SNE] Computed conditional probabilities for sample 62000 / 62284
# [t-SNE] Computed conditional probabilities for sample 62284 / 62284
# [t-SNE] Mean sigma: 0.862541
# [t-SNE] Computed conditional probabilities in 4.470s
# [t-SNE] Iteration 50: error = 108.4292297, gradient norm = 0.0000035 (50 iterations in 45.310s)
# [t-SNE] Iteration 100: error = 97.1525726, gradient norm = 0.0031476 (50 iterations in 39.904s)
# [t-SNE] Iteration 150: error = 82.6157684, gradient norm = 0.0013340 (50 iterations in 34.276s)
# [t-SNE] Iteration 200: error = 77.8266754, gradient norm = 0.0008872 (50 iterations in 33.998s)
# [t-SNE] Iteration 250: error = 75.1247787, gradient norm = 0.0006880 (50 iterations in 32.909s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 75.124779
# [t-SNE] Iteration 300: error = 3.5703659, gradient norm = 0.0008860 (50 iterations in 32.204s)
# [t-SNE] Iteration 350: error = 3.1800604, gradient norm = 0.0006560 (50 iterations in 31.119s)
# [t-SNE] Iteration 400: error = 2.8106532, gradient norm = 0.0004843 (50 iterations in 32.149s)
# [t-SNE] Iteration 450: error = 2.5086377, gradient norm = 0.0003716 (50 iterations in 31.956s)
# [t-SNE] Iteration 500: error = 2.2666960, gradient norm = 0.0002955 (50 iterations in 32.073s)
# [t-SNE] Iteration 550: error = 2.0727282, gradient norm = 0.0002421 (50 iterations in 31.431s)
# [t-SNE] Iteration 600: error = 1.9130185, gradient norm = 0.0002029 (50 iterations in 30.566s)
# [t-SNE] Iteration 650: error = 1.7776976, gradient norm = 0.0001733 (50 iterations in 31.007s)
# [t-SNE] Iteration 700: error = 1.6642332, gradient norm = 0.0001503 (50 iterations in 30.415s)
# [t-SNE] Iteration 750: error = 1.5675927, gradient norm = 0.0001320 (50 iterations in 38.929s)
# [t-SNE] Iteration 800: error = 1.4842958, gradient norm = 0.0001171 (50 iterations in 30.246s)
# [t-SNE] Iteration 850: error = 1.4119983, gradient norm = 0.0001048 (50 iterations in 30.286s)
# [t-SNE] Iteration 900: error = 1.3486114, gradient norm = 0.0000945 (50 iterations in 30.302s)
# [t-SNE] Iteration 950: error = 1.2925756, gradient norm = 0.0000859 (50 iterations in 32.598s)
# [t-SNE] Iteration 1000: error = 1.2426617, gradient norm = 0.0000784 (50 iterations in 31.509s)
# [t-SNE] KL divergence after 1000 iterations: 1.242662

# %%
best_cluster_kmean(X_tsne, "TSNE PCA")

# %%
data_15_months['cluster_tsne_km'] = kmean_labels(16, X_tsne)

# %%
data_15_months.to_csv("data/results/data_15_months.csv")

# %%
data_result['cluster_15_months'] = data_15_months['cluster_tsne_km']

# %%
del X_15
del X_tsne
del data_15_months

# %% [markdown]
# #### 7.2.5 - 18 mois

# %%
X_tsne = tsne_projected(X_18)
# Out:
# [t-SNE] Computing 211 nearest neighbors...
# [t-SNE] Indexed 81450 samples in 29.135s...
# [t-SNE] Computed neighbors for 81450 samples in 950.687s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 81450
# [t-SNE] Computed conditional probabilities for sample 2000 / 81450
# [t-SNE] Computed conditional probabilities for sample 3000 / 81450
# [t-SNE] Computed conditional probabilities for sample 4000 / 81450
# [t-SNE] Computed conditional probabilities for sample 5000 / 81450
# [t-SNE] Computed conditional probabilities for sample 6000 / 81450
# [t-SNE] Computed conditional probabilities for sample 7000 / 81450
# [t-SNE] Computed conditional probabilities for sample 8000 / 81450
# [t-SNE] Computed conditional probabilities for sample 9000 / 81450
# [t-SNE] Computed conditional probabilities for sample 10000 / 81450
# [t-SNE] Computed conditional probabilities for sample 11000 / 81450
# [t-SNE] Computed conditional probabilities for sample 12000 / 81450
# [t-SNE] Computed conditional probabilities for sample 13000 / 81450
# [t-SNE] Computed conditional probabilities for sample 14000 / 81450
# [t-SNE] Computed conditional probabilities for sample 15000 / 81450
# [t-SNE] Computed conditional probabilities for sample 16000 / 81450
# [t-SNE] Computed conditional probabilities for sample 17000 / 81450
# [t-SNE] Computed conditional probabilities for sample 18000 / 81450
# [t-SNE] Computed conditional probabilities for sample 19000 / 81450
# [t-SNE] Computed conditional probabilities for sample 20000 / 81450
# [t-SNE] Computed conditional probabilities for sample 21000 / 81450
# [t-SNE] Computed conditional probabilities for sample 22000 / 81450
# [t-SNE] Computed conditional probabilities for sample 23000 / 81450
# [t-SNE] Computed conditional probabilities for sample 24000 / 81450
# [t-SNE] Computed conditional probabilities for sample 25000 / 81450
# [t-SNE] Computed conditional probabilities for sample 26000 / 81450
# [t-SNE] Computed conditional probabilities for sample 27000 / 81450
# [t-SNE] Computed conditional probabilities for sample 28000 / 81450
# [t-SNE] Computed conditional probabilities for sample 29000 / 81450
# [t-SNE] Computed conditional probabilities for sample 30000 / 81450
# [t-SNE] Computed conditional probabilities for sample 31000 / 81450
# [t-SNE] Computed conditional probabilities for sample 32000 / 81450
# [t-SNE] Computed conditional probabilities for sample 33000 / 81450
# [t-SNE] Computed conditional probabilities for sample 34000 / 81450
# [t-SNE] Computed conditional probabilities for sample 35000 / 81450
# [t-SNE] Computed conditional probabilities for sample 36000 / 81450
# [t-SNE] Computed conditional probabilities for sample 37000 / 81450
# [t-SNE] Computed conditional probabilities for sample 38000 / 81450
# [t-SNE] Computed conditional probabilities for sample 39000 / 81450
# [t-SNE] Computed conditional probabilities for sample 40000 / 81450
# [t-SNE] Computed conditional probabilities for sample 41000 / 81450
# [t-SNE] Computed conditional probabilities for sample 42000 / 81450
# [t-SNE] Computed conditional probabilities for sample 43000 / 81450
# [t-SNE] Computed conditional probabilities for sample 44000 / 81450
# [t-SNE] Computed conditional probabilities for sample 45000 / 81450
# [t-SNE] Computed conditional probabilities for sample 46000 / 81450
# [t-SNE] Computed conditional probabilities for sample 47000 / 81450
# [t-SNE] Computed conditional probabilities for sample 48000 / 81450
# [t-SNE] Computed conditional probabilities for sample 49000 / 81450
# [t-SNE] Computed conditional probabilities for sample 50000 / 81450
# [t-SNE] Computed conditional probabilities for sample 51000 / 81450
# [t-SNE] Computed conditional probabilities for sample 52000 / 81450
# [t-SNE] Computed conditional probabilities for sample 53000 / 81450
# [t-SNE] Computed conditional probabilities for sample 54000 / 81450
# [t-SNE] Computed conditional probabilities for sample 55000 / 81450
# [t-SNE] Computed conditional probabilities for sample 56000 / 81450
# [t-SNE] Computed conditional probabilities for sample 57000 / 81450
# [t-SNE] Computed conditional probabilities for sample 58000 / 81450
# [t-SNE] Computed conditional probabilities for sample 59000 / 81450
# [t-SNE] Computed conditional probabilities for sample 60000 / 81450
# [t-SNE] Computed conditional probabilities for sample 61000 / 81450
# [t-SNE] Computed conditional probabilities for sample 62000 / 81450
# [t-SNE] Computed conditional probabilities for sample 63000 / 81450
# [t-SNE] Computed conditional probabilities for sample 64000 / 81450
# [t-SNE] Computed conditional probabilities for sample 65000 / 81450
# [t-SNE] Computed conditional probabilities for sample 66000 / 81450
# [t-SNE] Computed conditional probabilities for sample 67000 / 81450
# [t-SNE] Computed conditional probabilities for sample 68000 / 81450
# [t-SNE] Computed conditional probabilities for sample 69000 / 81450
# [t-SNE] Computed conditional probabilities for sample 70000 / 81450
# [t-SNE] Computed conditional probabilities for sample 71000 / 81450
# [t-SNE] Computed conditional probabilities for sample 72000 / 81450
# [t-SNE] Computed conditional probabilities for sample 73000 / 81450
# [t-SNE] Computed conditional probabilities for sample 74000 / 81450
# [t-SNE] Computed conditional probabilities for sample 75000 / 81450
# [t-SNE] Computed conditional probabilities for sample 76000 / 81450
# [t-SNE] Computed conditional probabilities for sample 77000 / 81450
# [t-SNE] Computed conditional probabilities for sample 78000 / 81450
# [t-SNE] Computed conditional probabilities for sample 79000 / 81450
# [t-SNE] Computed conditional probabilities for sample 80000 / 81450
# [t-SNE] Computed conditional probabilities for sample 81000 / 81450
# [t-SNE] Computed conditional probabilities for sample 81450 / 81450
# [t-SNE] Mean sigma: 0.715435
# [t-SNE] Computed conditional probabilities in 8.300s
# [t-SNE] Iteration 50: error = 111.0971832, gradient norm = 0.0000014 (50 iterations in 73.864s)
# [t-SNE] Iteration 100: error = 107.5176620, gradient norm = 0.0027309 (50 iterations in 89.551s)
# [t-SNE] Iteration 150: error = 86.8128357, gradient norm = 0.0013428 (50 iterations in 46.066s)
# [t-SNE] Iteration 200: error = 80.7819214, gradient norm = 0.0008819 (50 iterations in 45.226s)
# [t-SNE] Iteration 250: error = 77.4920120, gradient norm = 0.0006748 (50 iterations in 43.594s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 77.492012
# [t-SNE] Iteration 300: error = 3.8404608, gradient norm = 0.0007998 (50 iterations in 42.531s)
# [t-SNE] Iteration 350: error = 3.4948087, gradient norm = 0.0006217 (50 iterations in 41.534s)
# [t-SNE] Iteration 400: error = 3.1448629, gradient norm = 0.0004772 (50 iterations in 40.524s)
# [t-SNE] Iteration 450: error = 2.8424366, gradient norm = 0.0003747 (50 iterations in 40.076s)
# [t-SNE] Iteration 500: error = 2.5923617, gradient norm = 0.0003033 (50 iterations in 40.262s)
# [t-SNE] Iteration 550: error = 2.3864434, gradient norm = 0.0002518 (50 iterations in 39.558s)
# [t-SNE] Iteration 600: error = 2.2149405, gradient norm = 0.0002131 (50 iterations in 39.283s)
# [t-SNE] Iteration 650: error = 2.0696676, gradient norm = 0.0001833 (50 iterations in 39.615s)
# [t-SNE] Iteration 700: error = 1.9450487, gradient norm = 0.0001600 (50 iterations in 39.123s)
# [t-SNE] Iteration 750: error = 1.8362795, gradient norm = 0.0001414 (50 iterations in 40.104s)
# [t-SNE] Iteration 800: error = 1.7415074, gradient norm = 0.0001260 (50 iterations in 40.926s)
# [t-SNE] Iteration 850: error = 1.6572574, gradient norm = 0.0001133 (50 iterations in 39.401s)
# [t-SNE] Iteration 900: error = 1.5823848, gradient norm = 0.0001026 (50 iterations in 39.332s)
# [t-SNE] Iteration 950: error = 1.5157994, gradient norm = 0.0000935 (50 iterations in 39.707s)
# [t-SNE] Iteration 1000: error = 1.4560729, gradient norm = 0.0000858 (50 iterations in 41.000s)
# [t-SNE] KL divergence after 1000 iterations: 1.456073

# %%
best_cluster_kmean(X_tsne, "TSNE PCA")

# %%
data_18_months['cluster_tsne_km'] = kmean_labels(18, X_tsne)

# %%
data_18_months.to_csv("data/results/data_18_months.csv")

# %%
data_result['cluster_18_months'] = data_18_months['cluster_tsne_km']

# %%
del X_18
del X_tsne
del data_18_months

# %% [markdown]
# #### 7.2.6 - all

# %%
X_tsne = tsne_projected(X_all)
# Out:
# [t-SNE] Computing 211 nearest neighbors...
# [t-SNE] Indexed 93790 samples in 35.884s...
# [t-SNE] Computed neighbors for 93790 samples in 1160.597s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 93790
# [t-SNE] Computed conditional probabilities for sample 2000 / 93790
# [t-SNE] Computed conditional probabilities for sample 3000 / 93790
# [t-SNE] Computed conditional probabilities for sample 4000 / 93790
# [t-SNE] Computed conditional probabilities for sample 5000 / 93790
# [t-SNE] Computed conditional probabilities for sample 6000 / 93790
# [t-SNE] Computed conditional probabilities for sample 7000 / 93790
# [t-SNE] Computed conditional probabilities for sample 8000 / 93790
# [t-SNE] Computed conditional probabilities for sample 9000 / 93790
# [t-SNE] Computed conditional probabilities for sample 10000 / 93790
# [t-SNE] Computed conditional probabilities for sample 11000 / 93790
# [t-SNE] Computed conditional probabilities for sample 12000 / 93790
# [t-SNE] Computed conditional probabilities for sample 13000 / 93790
# [t-SNE] Computed conditional probabilities for sample 14000 / 93790
# [t-SNE] Computed conditional probabilities for sample 15000 / 93790
# [t-SNE] Computed conditional probabilities for sample 16000 / 93790
# [t-SNE] Computed conditional probabilities for sample 17000 / 93790
# [t-SNE] Computed conditional probabilities for sample 18000 / 93790
# [t-SNE] Computed conditional probabilities for sample 19000 / 93790
# [t-SNE] Computed conditional probabilities for sample 20000 / 93790
# [t-SNE] Computed conditional probabilities for sample 21000 / 93790
# [t-SNE] Computed conditional probabilities for sample 22000 / 93790
# [t-SNE] Computed conditional probabilities for sample 23000 / 93790
# [t-SNE] Computed conditional probabilities for sample 24000 / 93790
# [t-SNE] Computed conditional probabilities for sample 25000 / 93790
# [t-SNE] Computed conditional probabilities for sample 26000 / 93790
# [t-SNE] Computed conditional probabilities for sample 27000 / 93790
# [t-SNE] Computed conditional probabilities for sample 28000 / 93790
# [t-SNE] Computed conditional probabilities for sample 29000 / 93790
# [t-SNE] Computed conditional probabilities for sample 30000 / 93790
# [t-SNE] Computed conditional probabilities for sample 31000 / 93790
# [t-SNE] Computed conditional probabilities for sample 32000 / 93790
# [t-SNE] Computed conditional probabilities for sample 33000 / 93790
# [t-SNE] Computed conditional probabilities for sample 34000 / 93790
# [t-SNE] Computed conditional probabilities for sample 35000 / 93790
# [t-SNE] Computed conditional probabilities for sample 36000 / 93790
# [t-SNE] Computed conditional probabilities for sample 37000 / 93790
# [t-SNE] Computed conditional probabilities for sample 38000 / 93790
# [t-SNE] Computed conditional probabilities for sample 39000 / 93790
# [t-SNE] Computed conditional probabilities for sample 40000 / 93790
# [t-SNE] Computed conditional probabilities for sample 41000 / 93790
# [t-SNE] Computed conditional probabilities for sample 42000 / 93790
# [t-SNE] Computed conditional probabilities for sample 43000 / 93790
# [t-SNE] Computed conditional probabilities for sample 44000 / 93790
# [t-SNE] Computed conditional probabilities for sample 45000 / 93790
# [t-SNE] Computed conditional probabilities for sample 46000 / 93790
# [t-SNE] Computed conditional probabilities for sample 47000 / 93790
# [t-SNE] Computed conditional probabilities for sample 48000 / 93790
# [t-SNE] Computed conditional probabilities for sample 49000 / 93790
# [t-SNE] Computed conditional probabilities for sample 50000 / 93790
# [t-SNE] Computed conditional probabilities for sample 51000 / 93790
# [t-SNE] Computed conditional probabilities for sample 52000 / 93790
# [t-SNE] Computed conditional probabilities for sample 53000 / 93790
# [t-SNE] Computed conditional probabilities for sample 54000 / 93790
# [t-SNE] Computed conditional probabilities for sample 55000 / 93790
# [t-SNE] Computed conditional probabilities for sample 56000 / 93790
# [t-SNE] Computed conditional probabilities for sample 57000 / 93790
# [t-SNE] Computed conditional probabilities for sample 58000 / 93790
# [t-SNE] Computed conditional probabilities for sample 59000 / 93790
# [t-SNE] Computed conditional probabilities for sample 60000 / 93790
# [t-SNE] Computed conditional probabilities for sample 61000 / 93790
# [t-SNE] Computed conditional probabilities for sample 62000 / 93790
# [t-SNE] Computed conditional probabilities for sample 63000 / 93790
# [t-SNE] Computed conditional probabilities for sample 64000 / 93790
# [t-SNE] Computed conditional probabilities for sample 65000 / 93790
# [t-SNE] Computed conditional probabilities for sample 66000 / 93790
# [t-SNE] Computed conditional probabilities for sample 67000 / 93790
# [t-SNE] Computed conditional probabilities for sample 68000 / 93790
# [t-SNE] Computed conditional probabilities for sample 69000 / 93790
# [t-SNE] Computed conditional probabilities for sample 70000 / 93790
# [t-SNE] Computed conditional probabilities for sample 71000 / 93790
# [t-SNE] Computed conditional probabilities for sample 72000 / 93790
# [t-SNE] Computed conditional probabilities for sample 73000 / 93790
# [t-SNE] Computed conditional probabilities for sample 74000 / 93790
# [t-SNE] Computed conditional probabilities for sample 75000 / 93790
# [t-SNE] Computed conditional probabilities for sample 76000 / 93790
# [t-SNE] Computed conditional probabilities for sample 77000 / 93790
# [t-SNE] Computed conditional probabilities for sample 78000 / 93790
# [t-SNE] Computed conditional probabilities for sample 79000 / 93790
# [t-SNE] Computed conditional probabilities for sample 80000 / 93790
# [t-SNE] Computed conditional probabilities for sample 81000 / 93790
# [t-SNE] Computed conditional probabilities for sample 82000 / 93790
# [t-SNE] Computed conditional probabilities for sample 83000 / 93790
# [t-SNE] Computed conditional probabilities for sample 84000 / 93790
# [t-SNE] Computed conditional probabilities for sample 85000 / 93790
# [t-SNE] Computed conditional probabilities for sample 86000 / 93790
# [t-SNE] Computed conditional probabilities for sample 87000 / 93790
# [t-SNE] Computed conditional probabilities for sample 88000 / 93790
# [t-SNE] Computed conditional probabilities for sample 89000 / 93790
# [t-SNE] Computed conditional probabilities for sample 90000 / 93790
# [t-SNE] Computed conditional probabilities for sample 91000 / 93790
# [t-SNE] Computed conditional probabilities for sample 92000 / 93790
# [t-SNE] Computed conditional probabilities for sample 93000 / 93790
# [t-SNE] Computed conditional probabilities for sample 93790 / 93790
# [t-SNE] Mean sigma: 0.650648
# [t-SNE] Computed conditional probabilities in 6.739s
# [t-SNE] Iteration 50: error = 112.4817581, gradient norm = 0.0000011 (50 iterations in 64.138s)
# [t-SNE] Iteration 100: error = 111.4559402, gradient norm = 0.0019156 (50 iterations in 76.480s)
# [t-SNE] Iteration 150: error = 89.6844788, gradient norm = 0.0013345 (50 iterations in 50.084s)
# [t-SNE] Iteration 200: error = 82.7763290, gradient norm = 0.0008733 (50 iterations in 51.200s)
# [t-SNE] Iteration 250: error = 79.1212769, gradient norm = 0.0006838 (50 iterations in 47.630s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 79.121277
# [t-SNE] Iteration 300: error = 4.0071554, gradient norm = 0.0007705 (50 iterations in 47.402s)
# [t-SNE] Iteration 350: error = 3.6772439, gradient norm = 0.0006073 (50 iterations in 46.849s)
# [t-SNE] Iteration 400: error = 3.3338408, gradient norm = 0.0004741 (50 iterations in 57.547s)
# [t-SNE] Iteration 450: error = 3.0310619, gradient norm = 0.0003768 (50 iterations in 62.515s)
# [t-SNE] Iteration 500: error = 2.7775474, gradient norm = 0.0003071 (50 iterations in 58.668s)
# [t-SNE] Iteration 550: error = 2.5651903, gradient norm = 0.0002562 (50 iterations in 62.511s)
# [t-SNE] Iteration 600: error = 2.3872900, gradient norm = 0.0002177 (50 iterations in 53.198s)
# [t-SNE] Iteration 650: error = 2.2363517, gradient norm = 0.0001881 (50 iterations in 47.401s)
# [t-SNE] Iteration 700: error = 2.1063955, gradient norm = 0.0001649 (50 iterations in 45.419s)
# [t-SNE] Iteration 750: error = 1.9930071, gradient norm = 0.0001461 (50 iterations in 60.986s)
# [t-SNE] Iteration 800: error = 1.8920522, gradient norm = 0.0001305 (50 iterations in 43.002s)
# [t-SNE] Iteration 850: error = 1.8028024, gradient norm = 0.0001177 (50 iterations in 43.963s)
# [t-SNE] Iteration 900: error = 1.7232754, gradient norm = 0.0001068 (50 iterations in 43.261s)
# [t-SNE] Iteration 950: error = 1.6520810, gradient norm = 0.0000974 (50 iterations in 47.730s)
# [t-SNE] Iteration 1000: error = 1.5875832, gradient norm = 0.0000894 (50 iterations in 43.025s)
# [t-SNE] KL divergence after 1000 iterations: 1.587583

# %%
best_cluster_kmean(X_tsne, "TSNE")

# %%
data_all['cluster_tsne_km'] = kmean_labels(16, X_tsne)

# %%
data_all.to_csv("data/results/data_all_months.csv")

# %%
data_result['cluster_all'] = data_all['cluster_tsne_km']

# %%
del X_all
del X_tsne
del data_all

# %% [markdown]
# ## 8 - Analyse des résultats

# %%
data_result
# Out:
#                                   cluster_3_months  cluster_6_months  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2               NaN               NaN
# 0000b849f77a49e4a4ce2b2a4ca5be3f               NaN               NaN
# 0000f46a3911fa3c0805444483337064               2.0              12.0
# 0000f6ccb0745a6a4b88665a16c9f078               NaN               NaN
# 0004aac84e0df4da2b147fca70cf8255               NaN               NaN
# ...                                            ...               ...
# fffcf5a5ff07b0908bd4e2dbc735a684               NaN               3.0
# fffea47cd6d3cc0a88bd621562a9d061               NaN               NaN
# ffff371b4d645b6ecea244b27531430a              14.0               7.0
# ffff5962728ec6157033ef9805bacc48               NaN               NaN
# ffffd2657e2aad2907e67c3e9daecbeb               NaN               7.0
#
#                                   cluster_9_months  cluster_12_months  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2               NaN                NaN
# 0000b849f77a49e4a4ce2b2a4ca5be3f               NaN                NaN
# 0000f46a3911fa3c0805444483337064              14.0               18.0
# 0000f6ccb0745a6a4b88665a16c9f078               NaN                0.0
# 0004aac84e0df4da2b147fca70cf8255               NaN                4.0
# ...                                            ...                ...
# fffcf5a5ff07b0908bd4e2dbc735a684              16.0               16.0
# fffea47cd6d3cc0a88bd621562a9d061               NaN               11.0
# ffff371b4d645b6ecea244b27531430a              15.0                6.0
# ffff5962728ec6157033ef9805bacc48               NaN                NaN
# ffffd2657e2aad2907e67c3e9daecbeb               6.0               18.0
#
#                                   cluster_15_months  cluster_18_months  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                NaN               12.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                NaN                5.0
# 0000f46a3911fa3c0805444483337064                2.0                2.0
# 0000f6ccb0745a6a4b88665a16c9f078               14.0                6.0
# 0004aac84e0df4da2b147fca70cf8255                0.0                7.0
# ...                                             ...                ...
# fffcf5a5ff07b0908bd4e2dbc735a684               15.0                8.0
# fffea47cd6d3cc0a88bd621562a9d061                4.0               17.0
# ffff371b4d645b6ecea244b27531430a               13.0                7.0
# ffff5962728ec6157033ef9805bacc48                NaN                0.0
# ffffd2657e2aad2907e67c3e9daecbeb                3.0                0.0
#
#                                   cluster_all
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2            6
# 0000b849f77a49e4a4ce2b2a4ca5be3f            0
# 0000f46a3911fa3c0805444483337064           10
# 0000f6ccb0745a6a4b88665a16c9f078           11
# 0004aac84e0df4da2b147fca70cf8255           11
# ...                                       ...
# fffcf5a5ff07b0908bd4e2dbc735a684            0
# fffea47cd6d3cc0a88bd621562a9d061            4
# ffff371b4d645b6ecea244b27531430a            5
# ffff5962728ec6157033ef9805bacc48            2
# ffffd2657e2aad2907e67c3e9daecbeb           14
#
# [93790 rows x 7 columns]

# %%
data_based_3_months = data_result[:][data_result["cluster_3_months"].notnull()]

# %%
data_frequency = pd.DataFrame(index=["AMI Score", 'AR Score'])

# %%
AMI_3_months = metrics.adjusted_mutual_info_score(data_based_3_months["cluster_3_months"],
                                                  data_based_3_months["cluster_3_months"],
                                                  average_method='arithmetic')
AR_3_months = metrics.adjusted_rand_score(data_based_3_months["cluster_3_months"],
                                          data_based_3_months["cluster_3_months"])
NMI_3_months = metrics.normalized_mutual_info_score(data_based_3_months["cluster_3_months"],
                                                    data_based_3_months["cluster_3_months"],
                                                    average_method='arithmetic')

# %%
AMI_6_months = metrics.adjusted_mutual_info_score(data_based_3_months["cluster_3_months"],
                                                  data_based_3_months["cluster_6_months"],
                                                  average_method='arithmetic')
AR_6_months = metrics.adjusted_rand_score(data_based_3_months["cluster_3_months"],
                                          data_based_3_months["cluster_6_months"])
NMI_6_months = metrics.normalized_mutual_info_score(data_based_3_months["cluster_3_months"],
                                                    data_based_3_months["cluster_6_months"],
                                                    average_method='arithmetic')

# %%
AMI_9_months = metrics.adjusted_mutual_info_score(data_based_3_months["cluster_3_months"],
                                                  data_based_3_months["cluster_9_months"],
                                                  average_method="arithmetic")
AR_9_months = metrics.adjusted_rand_score(data_based_3_months["cluster_3_months"],
                                          data_based_3_months["cluster_9_months"])
NMI_9_months = metrics.normalized_mutual_info_score(data_based_3_months["cluster_3_months"],
                                                    data_based_3_months["cluster_9_months"],
                                                    average_method='arithmetic')

# %%
AMI_12_months = metrics.adjusted_mutual_info_score(data_based_3_months["cluster_3_months"],
                                                   data_based_3_months["cluster_12_months"],
                                                   average_method="arithmetic")
AR_12_months = metrics.adjusted_rand_score(data_based_3_months["cluster_3_months"],
                                           data_based_3_months["cluster_12_months"])
NMI_12_months = metrics.normalized_mutual_info_score(data_based_3_months["cluster_3_months"],
                                                     data_based_3_months["cluster_12_months"],
                                                     average_method='arithmetic')

# %%
AMI_15_months = metrics.adjusted_mutual_info_score(data_based_3_months["cluster_3_months"],
                                                   data_based_3_months["cluster_15_months"],
                                                   average_method="arithmetic")
AR_15_months = metrics.adjusted_rand_score(data_based_3_months["cluster_3_months"],
                                           data_based_3_months["cluster_15_months"])
NMI_15_months = metrics.normalized_mutual_info_score(data_based_3_months["cluster_3_months"],
                                                     data_based_3_months["cluster_15_months"],
                                                     average_method='arithmetic')

# %%
AMI_18_months = metrics.adjusted_mutual_info_score(data_based_3_months["cluster_3_months"],
                                                   data_based_3_months["cluster_18_months"],
                                                   average_method="arithmetic")
AR_18_months = metrics.adjusted_rand_score(data_based_3_months["cluster_3_months"],
                                           data_based_3_months["cluster_18_months"])
NMI_18_months = metrics.normalized_mutual_info_score(data_based_3_months["cluster_3_months"],
                                                     data_based_3_months["cluster_18_months"],
                                                     average_method='arithmetic')

# %%
AMI_all = metrics.adjusted_mutual_info_score(data_based_3_months["cluster_3_months"],
                                             data_based_3_months["cluster_all"],
                                             average_method="arithmetic")
AR_all = metrics.adjusted_rand_score(data_based_3_months["cluster_3_months"],
                                     data_based_3_months["cluster_all"])
NMI_all = metrics.normalized_mutual_info_score(data_based_3_months["cluster_3_months"],
                                               data_based_3_months["cluster_all"],
                                               average_method='arithmetic')

# %%
data_frequency.loc["AMI Score", "cluster_3_months"] = AMI_3_months
data_frequency.loc["AMI Score", "cluster_6_months"] = AMI_6_months
data_frequency.loc["AMI Score", "cluster_9_months"] = AMI_9_months
data_frequency.loc["AMI Score", "cluster_12_months"] = AMI_12_months
data_frequency.loc["AMI Score", "cluster_15_months"] = AMI_15_months
data_frequency.loc["AMI Score", "cluster_18_months"] = AMI_18_months
data_frequency.loc["AMI Score", "cluster_all"] = AMI_all

data_frequency.loc["AR Score", "cluster_3_months"] = AR_3_months
data_frequency.loc["AR Score", "cluster_6_months"] = AR_6_months
data_frequency.loc["AR Score", "cluster_9_months"] = AR_9_months
data_frequency.loc["AR Score", "cluster_12_months"] = AR_12_months
data_frequency.loc["AR Score", "cluster_15_months"] = AR_15_months
data_frequency.loc["AR Score", "cluster_18_months"] = AR_18_months
data_frequency.loc["AR Score", "cluster_all"] = AR_all

data_frequency.loc["NMI Score", "cluster_3_months"] = NMI_3_months
data_frequency.loc["NMI Score", "cluster_6_months"] = NMI_6_months
data_frequency.loc["NMI Score", "cluster_9_months"] = NMI_9_months
data_frequency.loc["NMI Score", "cluster_12_months"] = NMI_12_months
data_frequency.loc["NMI Score", "cluster_15_months"] = NMI_15_months
data_frequency.loc["NMI Score", "cluster_18_months"] = NMI_18_months
data_frequency.loc["NMI Score", "cluster_all"] = NMI_all

data_frequency.loc["# Cluster", "cluster_3_months"] = 17
data_frequency.loc["# Cluster", "cluster_6_months"] = 17
data_frequency.loc["# Cluster", "cluster_9_months"] = 17
data_frequency.loc["# Cluster", "cluster_12_months"] = 19
data_frequency.loc["# Cluster", "cluster_15_months"] = 16
data_frequency.loc["# Cluster", "cluster_18_months"] = 18
data_frequency.loc["# Cluster", "cluster_all"] = 16

# %%
data_frequency
# Out:
#            cluster_3_months  cluster_6_months  cluster_9_months  \
# AMI Score               1.0          0.597059          0.565700
# AR Score                1.0          0.402301          0.381458
# NMI Score               1.0          0.600714          0.569851
# # Cluster              17.0         17.000000         17.000000
#
#            cluster_12_months  cluster_15_months  cluster_18_months  \
# AMI Score           0.514272           0.438497           0.456106
# AR Score            0.296678           0.214506           0.234786
# NMI Score           0.519382           0.443572           0.461560
# # Cluster          19.000000          16.000000          18.000000
#
#            cluster_all
# AMI Score     0.409133
# AR Score      0.203575
# NMI Score     0.414467
# # Cluster    16.000000

# %%
data_frequency.to_csv("data/results/result.csv")

# %%
data_frequency = pd.read_csv(
    "data/results/result.csv", index_col=[0])

# %%
plt.figure(figsize=(10, 5))
data_frequency.loc["AMI Score"].plot(kind="bar")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
data_frequency.loc["AR Score"].plot(kind="bar")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
data_frequency.loc["NMI Score"].plot(kind="bar")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
data_frequency.loc["# Cluster"].plot(kind="bar")
plt.tight_layout()
plt.show()
